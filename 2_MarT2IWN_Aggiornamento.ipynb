# %% [markdown]
# # MariTerm 2 IWN

# %% [markdown]
# Importazione librerie e definizione variabili principali

# %%
import csv
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import string
import xml.etree.ElementTree as ET
from xml.dom import minidom

MariT = 'C:/Users/lucia/OneDrive/Desktop/Tirocinio/XML/MariT_03_24.xml'
ItalWN = 'C:/Users/lucia/OneDrive/Desktop/Tirocinio/XML/IWN_03_24.xml'
candidates_csv = 'C:/Users/lucia/OneDrive/Desktop/candidates_06_24.csv'
breakdown_csv = 'C:/Users/lucia/OneDrive/Desktop/breakdown_07_24.csv'
filt_mart = 'C:/Users/lucia/OneDrive/Desktop/MariT_f_07_24.xml'
filt_iwn = 'C:/Users/lucia/OneDrive/Desktop/IWN_f_07_24.xml'
updates = 'C:/Users/lucia/OneDrive/Desktop/IWN_align_08_24.xml'
New_IWN = 'C:/Users/lucia/OneDrive/Desktop/prel_IWN_09_24.xml'
finalized_IWN = 'C:/Users/lucia/OneDrive/Desktop/IWN_09_24.xml'
plug_att = 'C:/Users/lucia/OneDrive/Desktop/PROV_IWN_09_24.xml'


def parse_xml(file_path):
    return ET.parse(file_path).getroot()

# %% [markdown]
# # Parte 1
# a. Calcolo delle similarità tra coppie di voci
#
# b. Salvataggio dei metadati in formato csv
#
# c. Salvataggio delle voci accoppiate in XML filtrati

# %%
def normalize_lemma(lemma):
    """Replace underscores with spaces in lemma, replace apostrophes with spaces, and lowercase the text."""
    return lemma.replace('_', ' ').lower().replace("'", " ").translate(str.maketrans('', '', string.punctuation.replace("'", ""))) if lemma else ""

def normalize_text(text):
    """Lowercase, replace underscores with spaces, replace apostrophes with spaces, and remove other punctuation from text."""
    text = text.lower().replace('_', ' ').replace("'", " ")  # Replace underscores and apostrophes with spaces
    return text.translate(str.maketrans('', '', string.punctuation.replace("'", "")))  # Remove all other punctuation

def extract_word_meanings(xml_root):
    word_meanings = []
    for word_meaning in xml_root.findall(".//WORD_MEANING"):
        lemma_variants = word_meaning.find("VARIANTS")
        lemmas = [literal.get("LEMMA") for literal in lemma_variants.findall("LITERAL") if literal.get("LEMMA")]
        normalized_lemmas = [normalize_lemma(lemma) for lemma in lemmas]
        
        senses = [literal.get("SENSE") for literal in lemma_variants.findall("LITERAL") if literal.get("SENSE")]
        normalized_senses = [normalize_text(sense) for sense in senses]
        
        gloss = word_meaning.find("GLOSS").text or ""
        normalized_gloss = normalize_text(gloss)
        
        relations = []
        for relation in word_meaning.findall(".//INTERNAL_LINKS/RELATION"):
            target_wm = relation.find("TARGET_WM")
            if target_wm is not None:
                target_id = target_wm.get("ID")
                target_lemma = target_wm.get("LEMMA")
                normalized_target_lemma = normalize_lemma(target_lemma)
                
                target_gloss = target_wm.get("GLOSS", "No Gloss")
                normalized_target_gloss = normalize_text(target_gloss)
                
                relation_type = relation.get("TYPE")
                if relation_type in {"has_hyperonym", "has_hyponym", "near_synonym", "has_xpos_hyperonym", "has_xpos_hyponym", "xpos_near_synonym"}:
                    relations.append({
                        "relation_type": relation_type,
                        "target_id": target_id,
                        "target_lemma": target_lemma,
                        "normalized_target_lemma": normalized_target_lemma,
                        "target_gloss": target_gloss,
                        "normalized_target_gloss": normalized_target_gloss
                    })
        
        first_literal = lemma_variants.find("LITERAL")
        first_literal_lemma = first_literal.get("LEMMA") if first_literal is not None else "No Literal Lemma"
        normalized_first_literal_lemma = normalize_lemma(first_literal_lemma)
        
        first_literal_sense = first_literal.get("SENSE") if first_literal is not None else "No Sense"
        normalized_first_literal_sense = normalize_text(first_literal_sense)
        
        word_meanings.append({
            "id": word_meaning.get("ID"),
            "lemmas": lemmas,
            "normalized_lemmas": normalized_lemmas,
            "senses": senses,
            "normalized_senses": normalized_senses,
            "gloss": gloss,
            "normalized_gloss": normalized_gloss,
            "relations": relations,
            "first_literal_lemma": first_literal_lemma,
            "normalized_first_literal_lemma": normalized_first_literal_lemma,
            "first_literal_sense": first_literal_sense,
            "normalized_first_literal_sense": normalized_first_literal_sense,
            "part_of_speech": word_meaning.get("PART_OF_SPEECH")
        })
    return word_meanings

def calculate_gloss_similarity(text1, text2):
    text1 = normalize_text(text1)
    text2 = normalize_text(text2)
    if not text1.strip() or not text2.strip():
        return 0.0

    vectorizer = TfidfVectorizer()
    try:
        tfidf = vectorizer.fit_transform([text1, text2])
        return cosine_similarity(tfidf[0:1], tfidf[1:2])[0][0]
    except ValueError as e:
        print(f"Error calculating gloss similarity: {e}")
        return 0.0

def calculate_relation_similarity(wn_g_sim, relations1, relations2):
    weights = {
        "has_hyperonym": 0.82,
        "has_hyponym": 0.76,
        "near_synonym": 0.6,
        "has_xpos_hyperonym": 0.5,
        "has_xpos_hyponym": 0.5,
        "xpos_near_synonym": 0.5
    }
    
    relation_weights = {}
    total_weighted_similarity = 0
    bonus = 0
    malus = 0
    bonus_relations = []
    malus_count = 0
    missing_relations_details = []
    no_gloss_relations = []
    no_gloss_words = []
    
    relations1_dict = {(r["relation_type"], r["target_lemma"]): r["target_gloss"] for r in relations1}
    relations2_dict = {(r["relation_type"], r["target_lemma"]): r["target_gloss"] for r in relations2}
    
    for key, mari_gloss in relations1_dict.items():
        if key in relations2_dict:
            ital_gloss = relations2_dict[key]
            
            if (mari_gloss != "No Gloss" and ital_gloss == "No Gloss") or (mari_gloss == "No Gloss" and ital_gloss != "No Gloss"):
                gloss_similarity = 0.5
            else:
                gloss_similarity = calculate_gloss_similarity(mari_gloss, ital_gloss)
            
            weight = weights.get(key[0], 0)
            weighted_similarity = gloss_similarity * weight
            
            relation_weights[key] = (weighted_similarity, gloss_similarity, weight)
            total_weighted_similarity += weighted_similarity
            
            if (mari_gloss != "No Gloss" and ital_gloss != "No Gloss") or (mari_gloss == "No Gloss" and ital_gloss == "No Gloss"):
                bonus += 0.33
                bonus_relations.append(key[1])
            elif mari_gloss != "No Gloss" and ital_gloss == "No Gloss":
                malus -= 0.33
                no_gloss_relations.append(key[1])
                no_gloss_words.append(mari_gloss)
        else:
            malus -= 0.33
            missing_relations_details.append(key[1])
    
    total_similarity = wn_g_sim + total_weighted_similarity + bonus + malus
    malus_count = len(no_gloss_relations)
    
    return total_weighted_similarity, relation_weights, bonus, malus, malus_count, missing_relations_details, no_gloss_relations, no_gloss_words, total_similarity, bonus_relations

def format_relations(relations, relation_weights, show_scores=True):
    formatted_relations = []
    seen_relations = set()
    
    for rel in relations:
        if isinstance(rel, dict):
            rel_type = rel["relation_type"]
            target_lemma = rel["target_lemma"]
            target_gloss = rel.get("target_gloss", "No Gloss")
            key = (rel_type, target_lemma)
            
            if key not in seen_relations:
                seen_relations.add(key)
                if key in relation_weights and show_scores:
                    weight_score, gloss_similarity, weight = relation_weights[key]
                    formatted_relations.append(f"{rel_type}, {target_lemma}, {target_gloss} "
                        f"(Score: [{gloss_similarity:.2f}] * [{weight:.2f}] = {weight_score:.2f})")
                else:
                    formatted_relations.append(f"{rel_type}, {target_lemma}, {target_gloss} (Score: 0.00)")
                    
    return formatted_relations

def get_fallback_gloss(term, fallback_type='near_synonym'):
    # If a Word Meaning does not have a gloss, a fallback one is used. Check the primary fallback type first
    for relation_type in [fallback_type, 'near_xpos_synonym', 'has_hyponym', 'has_hyperonym']:
        for rel in term.get('relations', []):
            if rel.get('relation_type') == relation_type:
                target_gloss = rel.get('target_gloss', '')
                if target_gloss == "No Gloss":
                    target_gloss = ''  # Replace "No Gloss" with an empty string for comparison
                if target_gloss:
                    return target_gloss, relation_type
    return '', None  # If no valid fallback is found

def match_lemmas_with_alternate_senses(mari_term_wms, ital_wn_wms):
    results = []
    best_matches_per_ital_wn = {}
    seen_pairs = set()

    if not mari_term_wms or not ital_wn_wms:
        return results

    for wm1 in mari_term_wms:
        best_match = None
        best_gloss_similarity = -1
        best_total_weighted_relation_similarity = -1
        best_total_similarity = -1

        for wm2 in ital_wn_wms:
            if wm1.get("normalized_first_literal_lemma") == wm2.get("normalized_first_literal_lemma") and wm1.get("part_of_speech") == wm2.get("part_of_speech"):
                mari_gloss = wm1.get("normalized_gloss", "")
                ital_gloss = wm2.get("normalized_gloss", "")

                # Handle Mariterm fallback gloss
                if not mari_gloss.strip():
                    mari_gloss, mari_fallback_type = get_fallback_gloss(wm1, 'near_synonym')
                    fallback_used = True
                else:
                    mari_fallback_type = None
                    fallback_used = False
                
                # Handle ItalWN fallback gloss
                if not ital_gloss.strip():
                    ital_gloss, ital_fallback_type = get_fallback_gloss(wm2, 'near_synonym')
                    ital_fallback_used = True
                    if ital_gloss == 'No Gloss':
                        ital_gloss = ''  # Compare against an empty string instead of "No Gloss"
                else:
                    ital_fallback_type = None
                    ital_fallback_used = False

                wn_g_sim = calculate_gloss_similarity(mari_gloss, ital_gloss)

                if mari_fallback_type:
                    if mari_fallback_type == 'has_hyponym':
                        wn_g_sim -= 0.05
                    elif mari_fallback_type == 'has_hyperonym':
                        wn_g_sim -= 0.10
                
                if ital_fallback_used:
                    if ital_fallback_type == 'has_hyponym':
                        wn_g_sim -= 0.10
                    elif ital_fallback_type == 'has_hyperonym':
                        wn_g_sim -= 0.10

                total_weighted_similarity, relation_weights, bonus, malus, malus_count, missing_relations, no_gloss_relations, no_gloss_words, total_similarity, bonus_relations = calculate_relation_similarity(
                    wn_g_sim, wm1.get("relations", []), wm2.get("relations", [])
                )

                current_match = {
                    "Literal Lemma": wm1.get("first_literal_lemma", ""),
                    "MariT sense": wm1.get("first_literal_sense", ""),
                    "IWN sense": wm2.get("first_literal_sense", ""),
                    "Gloss S. (WM)": wn_g_sim,
                    "Total S.": total_similarity,
                    "T. Relation S.": total_weighted_similarity,
                    "Mariterm ID": wm1.get("id", ""),
                    "ItalWN ID": wm2.get("id", ""),
                    "Mariterm Gloss": mari_gloss if not fallback_used else f"[FALLBACK] {get_fallback_gloss(wm1, 'near_synonym')[0]}",
                    "ItalWN Gloss": ital_gloss if not ital_fallback_used else f"[FALLBACK] {get_fallback_gloss(wm2, 'near_synonym')[0]}",
                    "MariTerm Relations": format_relations(wm1.get("relations", []), relation_weights),
                    "ItalWN Relations": format_relations(wm2.get("relations", []), relation_weights),
                    "bonus": bonus,
                    "malus": malus,
                    "missing_relations": missing_relations,
                    "no_gloss_relations": no_gloss_relations,
                    "bonus_relations": bonus_relations,
                }

                # Track the best match across all possible pairs for this ItalWN entry
                if wn_g_sim > best_gloss_similarity or \
                   (wn_g_sim == best_gloss_similarity and total_weighted_similarity > best_total_weighted_relation_similarity) or \
                   (wn_g_sim == best_gloss_similarity and total_weighted_similarity == best_total_weighted_relation_similarity and total_similarity > best_total_similarity) or \
                   (wn_g_sim == best_gloss_similarity and total_weighted_similarity == best_total_weighted_relation_similarity and total_similarity == best_total_similarity):

                    best_gloss_similarity = wn_g_sim
                    best_total_weighted_relation_similarity = total_weighted_similarity
                    best_total_similarity = total_similarity
                    best_match = current_match

        # Apply the matching criteria based on thresholds
        if best_match:
            ital_wn_id = best_match.get('ItalWN ID')
            if best_match['Gloss S. (WM)'] >= 0.43 or best_match['T. Relation S.'] > 0:
                best_matches_per_ital_wn[ital_wn_id] = best_match
            elif best_match['Gloss S. (WM)'] >= 0.13 and (best_match['Gloss S. (WM)'] < 0.43 or best_match['T. Relation S.'] > 0):
                best_matches_per_ital_wn[ital_wn_id] = best_match
            elif best_match['T. Relation S.'] > 0.09 or (0.14 <= best_match['Gloss S. (WM)'] < 0.19) or (0.24 <= best_match['Gloss S. (WM)'] < 0.29) or best_match['Gloss S. (WM)'] >= 0.44:
                best_matches_per_ital_wn[ital_wn_id] = best_match

    results = [(match, []) for match in best_matches_per_ital_wn.values()]

    return results

def print_and_return_best_match(results):
    # Sort results by 'Total S.' in descending order
    sorted_results = sorted(results, key=lambda x: x[0].get('Total S.', 0), reverse=True)

    for best_match, matched_senses in sorted_results:
            mari_gloss = best_match.get('Mariterm Gloss', '').strip()
            ital_wn_gloss = best_match.get('ItalWN Gloss', '').strip()

            # Check if both glosses are empty
            if not mari_gloss and not ital_wn_gloss:
                print(f"\nLiteral Lemma: {best_match.get('Literal Lemma', 'N/A')}")
                print(f"MariTerm Gloss: [FALLBACK]")
                print(f"ItalWN Gloss: [FALLBACK]")
                print(f"MariTerm ID: {best_match['Mariterm ID']}")
                print(f"ItalWN ID: {best_match['ItalWN ID']}")
                print(f"MariTerm Sense: {best_match.get('MariT sense', 'N/A')}")
                print(f"ItalWN Sense: {best_match.get('IWN sense', 'N/A')}")
                print("No alternate senses available for comparison.")
                print(f"Gloss S. (WM): 0.00")
                print(f"Total Weighted Relation Similarity: 0.00")
                print(f"  Bonus: 0.00 (0/0 - )")
                print(f"  Malus: 0.00 (0/0 - No Gloss in ItalWN: 0,  - Missing: )")
                print(f"Total S.: 0.00")
                print(f"MariTerm Relations: ")
                print(f"ItalWN Relations: ")
            else:
                # Continue with fallback logic if either gloss is present
                if mari_gloss == '':
                    mari_gloss, mari_fallback_type = get_fallback_gloss(best_match, 'near_synonym')
                    fallback_used = True
                else:
                    mari_fallback_type = None
                    fallback_used = False
                
                if ital_wn_gloss == '':
                    ital_wn_gloss, ital_fallback_type = get_fallback_gloss(best_match, 'near_synonym')
                else:
                    ital_fallback_type = None

                print(f"\nLiteral Lemma: {best_match.get('Literal Lemma', 'N/A')}")
                print(f"MariTerm Gloss: {mari_gloss}")
                print(f"ItalWN Gloss: {ital_wn_gloss}")
                print(f"MariTerm ID: {best_match['Mariterm ID']}")
                print(f"ItalWN ID: {best_match['ItalWN ID']}")
                print(f"MariTerm Sense: {best_match.get('MariT sense', 'N/A')}")
                print(f"ItalWN Sense: {best_match.get('IWN sense', 'N/A')}")
                print(f"Gloss S. (WM): {best_match['Gloss S. (WM)']:.2f}")
                print(f"Total Weighted Relation Similarity: {best_match['T. Relation S.']:.2f}")
                print(f"  Bonus: {best_match['bonus']:.2f} ({len(best_match['bonus_relations'])}/{len(best_match['MariTerm Relations'])} - {', '.join(best_match['bonus_relations'])})")
                print(f"  Malus: {best_match['malus']:.2f} ({len(best_match['missing_relations']) + len(best_match['no_gloss_relations'])}/{len(best_match['MariTerm Relations'])} - No Gloss in ItalWN: {len(best_match['no_gloss_relations'])}, {', '.join(best_match['no_gloss_relations'])} - Missing: {', '.join(best_match['missing_relations'])})")
                print(f"Total S.: {best_match.get('Total S.', 0.0):.2f}")  # Default to 0.0 if 'Total S.' is not present
                print(f"MariTerm Relations:")
                for rel in best_match.get('MariTerm Relations', []):
                    print(f"   {rel}")
                print(f"ItalWN Relations:")
                for rel in best_match.get('ItalWN Relations', []):
                    print(f"   {rel}")

def score_candidates(MariT, ItalWN, candidates_file):
    mari_term_wms = extract_word_meanings(parse_xml(MariT))
    ital_wn_wms = extract_word_meanings(parse_xml(ItalWN))
    
    candidate_lemmas = pd.read_csv(candidates_file, delimiter=";")['Shared Lemma'].str.lower().apply(normalize_text).tolist()
    
    mari_term_wms = [wm for wm in mari_term_wms if any(normalized_lemma in candidate_lemmas for normalized_lemma in wm['normalized_lemmas'])]
    ital_wn_wms = [wm for wm in ital_wn_wms if any(normalized_lemma in candidate_lemmas for normalized_lemma in wm['normalized_lemmas'])]
    
    results = match_lemmas_with_alternate_senses(mari_term_wms, ital_wn_wms)
    print_and_return_best_match(results)

def save_entries(MariT, ItalWN, breakdown_csv):
    mari_term_wms = extract_word_meanings(parse_xml(MariT))
    ital_wn_wms = extract_word_meanings(parse_xml(ItalWN))

    candidate_lemmas = set(pd.read_csv(breakdown_csv, delimiter=';')['Shared Lemma'].str.lower().apply(normalize_text))

    mari_term_wms = [wm for wm in mari_term_wms if any(normalized_lemma in candidate_lemmas for normalized_lemma in wm['normalized_lemmas'])]
    ital_wn_wms = [wm for wm in ital_wn_wms if any(normalized_lemma in candidate_lemmas for normalized_lemma in wm['normalized_lemmas'])]

    results = match_lemmas_with_alternate_senses(mari_term_wms, ital_wn_wms)

    mari_term_id_to_ital_wn_ids = {}
    ital_wn_id_counts = {}

    for best_match, matched_senses in results:
        mari_term_id = best_match.get('Mariterm ID')
        ital_wn_id = best_match.get('ItalWN ID')

        if mari_term_id not in mari_term_id_to_ital_wn_ids:
            mari_term_id_to_ital_wn_ids[mari_term_id] = [ital_wn_id]
        else:
            mari_term_id_to_ital_wn_ids[mari_term_id].append(ital_wn_id)

        if ital_wn_id in ital_wn_id_counts:
            ital_wn_id_counts[ital_wn_id] += 1
        else:
            ital_wn_id_counts[ital_wn_id] = 1

    unique_entries = []

    for best_match, matched_senses in results:
        mari_term_id = best_match.get('Mariterm ID')
        ital_wn_id = best_match.get('ItalWN ID')

        if len(mari_term_id_to_ital_wn_ids[mari_term_id]) == 1 and ital_wn_id_counts[ital_wn_id] == 1:
            gloss = best_match.get("Mariterm Gloss", 'No Gloss Available')
            if "[FALLBACK]" in gloss:
                gloss = ''  # Remove the gloss entirely if it contains "[FALLBACK]"

            entry = {
                "Literal Lemma": best_match.get("Literal Lemma", 'N/A'),
                "Mariterm ID": mari_term_id,
                "Total S.": best_match.get("Total S.", 0.00),
                "Gloss S. (WM)": best_match.get("Gloss S. (WM)", 0.00),
                "T. Relation S.": best_match.get("T. Relation S.", 0.00),
                "Malus": best_match.get('malus', 0.00),  # Correctly storing malus
                "Bonus": best_match.get('bonus', 0.00),  # Correctly storing bonus
                "Mariterm Gloss": gloss,
                "MariT sense": best_match.get("MariT sense", 'N/A'),
                "IWN sense": best_match.get("IWN sense", 'N/A'),
                "MariTerm Relations": best_match.get("MariTerm Relations", []),
                "ItalWN Relations": best_match.get("ItalWN Relations", []),
            }
            unique_entries.append(entry)

    print(f"Unique Entries: {len(unique_entries)} entries generated.")  # Debugging information
    
    return unique_entries


unique_entries = save_entries(MariT, ItalWN, candidates_csv)
score_candidates(MariT, ItalWN, candidates_csv)
# Out:
# Unique Entries: 747 entries generated.
#
# Literal Lemma: nave militare
# MariTerm Gloss: nave impiegata per scopi militari eo di guerra
# ItalWN Gloss: [FALLBACK] nave dell'ammiraglio
# MariTerm ID: N#20
# ItalWN ID: N#49583
# MariTerm Sense: 1
# ItalWN Sense: 1
# Gloss S. (WM): 0.02
# Total Weighted Relation Similarity: 13.04
#   Bonus: 5.94 (18/23 - nave, ammiraglia, cacciasommergibili, cacciatorpediniere, cannoniera, corazzata, corvetta, fregata, incrociatore, lanciamissili, posamine, posareti, serrafila, silurante, sommergibile, torpediniera, vascello, vedetta)
#   Malus: -1.65 (5/23 - No Gloss in ItalWN: 0,  - Missing: barbotta, betta, dragamine, galea, portaerei)
# Total S.: 17.34
# MariTerm Relations:
#    has_hyperonym, nave, imbarcazione di una certa grandezza che  fornita di adeguati mezzi di propulsione  è adibita al trasporto di persone e merci o che  opportunamente attrezzata e armata  è impiegata in attività belliche.  (Score: [0.14] * [0.82] = 0.12)
#    has_hyponym, ammiraglia, nave dell'ammiraglio (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, barbotta, nave medievale da guerra con fianchi protetti da cuoio e sprone. (Score: 0.00)
#    has_hyponym, betta, piccola nave sussidiaria della Marina militare. (Score: 0.00)
#    has_hyponym, cacciasommergibili, No Gloss (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, cacciatorpediniere, nave militare (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, cannoniera, No Gloss (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, corazzata, grande nave da battaglia. (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, corvetta, nave militare  attualmente non superiore alle 1000 tonnellate  per scorta ai convogli e caccia ai sommergibili. (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, dragamine, nave militare (Score: 0.00)
#    has_hyponym, fregata, nave militare con compiti di scorta  con dislocamento fra 1650 e 7800 tonnellate. (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, galea, dal greco galeas  pesce spada  nave da guerra e da commercio usata nel Mediterraneo per oltre tremila anni  il suo uso declinò a partire dal XVII secolo  quando venne man mano soppiantata dai velieri  estinguendosi alla fine del XVIII secolo. (Score: 0.00)
#    has_hyponym, incrociatore, nave militare (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, lanciamissili, nave militare (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, portaerei, grande nave militare. (Score: 0.00)
#    has_hyponym, posamine, nave da guerra attrezzata per collocare mine in mare. (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, posareti, nave militare adibita al trasporto e alla posa di ostruzioni  spec. reti  a difesa di forze navali. (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, serrafila, nave militare che viene per ultima in una formazione che va alla stessa velocità (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, silurante, No Gloss (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, sommergibile, nave militare  destinata a navigare sott'acqua. (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, torpediniera, nave militare (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, vascello, grande nave da guerra a tre ponti  tre alberi altissimi  pezzi di artiglieria e moltissime vele  in uso fino alla metà del XIX secolo. (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, vedetta, nave militare piccola velocissima per la caccia ai sommergibili e la vigilanza costiera (Score: [1.00] * [0.76] = 0.76)
# ItalWN Relations:
#    has_hyperonym, nave, costruzione specialmente di notevoli dimensioni destinata al trasporto o a scopi militari spostandosi per via d'acqua  galleggiando  o navigando in profondità  o scivolando sopra la superficie. (Score: [0.14] * [0.82] = 0.12)
#    has_hyponym, ammiraglia, nave dell'ammiraglio (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, cacciasommergibili, No Gloss (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, cacciatorpediniere, nave militare (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, cannoniera, No Gloss (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, corazzata, grande nave da battaglia. (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, corvetta, nave militare  attualmente non superiore alle 1000 tonnellate  per scorta ai convogli e caccia ai sommergibili. (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, spazzamine, nave militare (Score: 0.00)
#    has_hyponym, fregata, nave militare con compiti di scorta  con dislocamento fra 1650 e 7800 tonnellate. (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, incrociatore, nave militare (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, lanciamissili, nave militare (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, motosilurante, unità navale della marina da guerra (Score: 0.00)
#    has_hyponym, portaeromobili, grande nave militare. (Score: 0.00)
#    has_hyponym, posamine, nave da guerra attrezzata per collocare mine in mare. (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, posareti, nave militare adibita al trasporto e alla posa di ostruzioni  spec. reti  a difesa di forze navali. (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, serrafila, nave militare che viene per ultima in una formazione che va alla stessa velocità  (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, silurante, No Gloss (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, sommergibile, nave militare  destinata a navigare sott'acqua. (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, torpediniera, nave militare (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, vascello, grande nave da guerra a tre ponti  tre alberi altissimi  pezzi di artiglieria e moltissime vele  in uso fino alla metà del XIX secolo. (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, vedetta, nave militare piccola velocissima per la caccia ai sommergibili e la vigilanza costiera (Score: [1.00] * [0.76] = 0.76)
#
# Literal Lemma: imbarcazione
# MariTerm Gloss: termine generico per indicare barche di piccole e medie dimensioni  utilizzate per diversi scopi lavoro  piacere  etc
# ItalWN Gloss: qualsiasi natante di dimensioni relativamente piccole
# MariTerm ID: N#58
# ItalWN ID: N#5211
# MariTerm Sense: 1
# ItalWN Sense: 1
# Gloss S. (WM): 0.18
# Total Weighted Relation Similarity: 11.85
#   Bonus: 6.27 (19/36 - mezzo, aliscafo, baleniera, barca, barcone, battello, fasello, idroplano, idroscivolante, iole, motoscafo, patino, nave_da_pesca, pilotina, piroga, sampang, sandolino, tender, trimarano)
#   Malus: -5.61 (17/36 - No Gloss in ItalWN: 0,  - Missing: acazia, barca a motore, barca a remi, barca a vela, barca di salvataggio, cajak, canotto, caracora, deriva, dumler, house-boat, motore fuoribordo, natante, natante da diporto, traghetto, panfilo, racer)
# Total S.: 12.69
# MariTerm Relations:
#    has_hyperonym, mezzo, qualunque mezzo di trasporto (Score: [1.00] * [0.82] = 0.82)
#    has_hyponym, acazia, antica imbarcazione greca  a remi con due o tre alberi e vele prima quadre e poi latine  bassa  lunga e assai veloce.  (Score: 0.00)
#    has_hyponym, aliscafo, imbarcazione a motore che naviga planando su alip oste ai lati dello scafo raggiungendo altissime velocità. (Score: [0.16] * [0.76] = 0.12)
#    has_hyponym, baleniera, imbarcazione a remi usata un tempo da comandanti e ammiragli (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, barca, imbarcazione di piccole dimensioni  a remi  a vela  o a motore aperta o parzialmente pontata. (Score: [0.41] * [0.76] = 0.31)
#    has_hyponym, barca a motore, imbarcazione con propulsione meccanica (Score: 0.00)
#    has_hyponym, barca a remi, imbarcazione con propulsione a remi (Score: 0.00)
#    has_hyponym, barca a vela, No Gloss (Score: 0.00)
#    has_hyponym, barca di salvataggio, imbarcazione ausiliaria  in genere di piccole dimensioni  tenuta a bordo per casi di emergenza. (Score: 0.00)
#    has_hyponym, barcone, grossa imbarcazione per il trasporto delle merci.  (Score: [0.74] * [0.76] = 0.56)
#    has_hyponym, battello, piccola imbarcazione a remi o a motore adibita a vari usi specifici. (Score: [0.13] * [0.76] = 0.10)
#    has_hyponym, cajak, canotto per una persona  fatto di pelli di foca cucite insieme e tese su una intelaiatura di legno  usato dagli Eschimesi per la caccia. (Score: 0.00)
#    has_hyponym, canotto, sulle navi mercantili è la più piccola delle imbarcazioni di bordo. (Score: 0.00)
#    has_hyponym, caracora, imbarcazione della Malesia  lunga e affilata. (Score: 0.00)
#    has_hyponym, deriva, piccola imbarcazione a vela  aperta e adatta a brevi navigazioni. (Score: 0.00)
#    has_hyponym, dumler, navicella pirata del sec. XVII. (Score: 0.00)
#    has_hyponym, fasello, antica imbarcazione veloce (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, house-boat, No Gloss (Score: 0.00)
#    has_hyponym, idroplano, natante a sostentazione idroplana (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, idroscivolante, imbarcazione propulsa con elica aerea (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, iole, piccola imbarcazione a remi o a vela per uso costiero. (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, motore fuoribordo, motore (normalmente di piccola-media potenza) fissato alla poppa di una imbarcazione a cui imprime il movimento  anche imbarcazione che sia dotata di tale tipo di motore. (Score: 0.00)
#    has_hyponym, motoscafo, imbarcazione spinta da motore a scoppio. (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, natante, imbarcazione di piccole o medie dimensioni non fornita di propulsione propria. (Score: 0.00)
#    has_hyponym, natante da diporto, piccola imbarcazione esente dall'obbligo di iscrizione nei registri delle autorità competenti. (Score: 0.00)
#    has_hyponym, traghetto, imbarcazione usata per traghettare. (Score: 0.00)
#    has_hyponym, panfilo, imbarcazione utilizzata per turismo  escursionismo o per le competizioni agonistiche.   (Score: 0.00)
#    has_hyponym, patino, imbarcazione da diporto  a remi o pedali (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, nave_da_pesca, imbarcazione o nave attrezzata per la pesca. (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, pilotina, No Gloss (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, piroga, No Gloss (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, racer, termine inglese che designa una imbarcazione da competizione  sia a vela che a motore. (Score: 0.00)
#    has_hyponym, sampang, imbarcazione a remi  usata su fiumi e acque costiere nell'Estremo Oriente. (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, sandolino, No Gloss (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, tender, imbarcazione di servizio utilizzato per scendere a terra da imbarcazioni più grandi. (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, trimarano, imbarcazione a vela formata da uno scafo centrale e due laterali più piccoli  paralleli e simmetrici  uniti con traverse metalliche o in vetroresina  allo scafo centrale. (Score: [0.08] * [0.76] = 0.06)
# ItalWN Relations:
#    has_hyperonym, mezzo, qualunque mezzo di trasporto (Score: [1.00] * [0.82] = 0.82)
#    has_hyponym, accone, solido barcone lungo e quadrato  già usato per trasportare a bordo  rimorchiandolo  il carico e l’armamento (Score: 0.00)
#    has_hyponym, albatrosso, tipo di nave inventata  verso la fine del ‘400  da mastro Giovanni dell’arsenale di Pisa. (Score: 0.00)
#    has_hyponym, aliscafo, imbarcazione a motore provvista di ali che ne aumentano la velocità sollevandola al pelo dell'acqua. (Score: [0.16] * [0.76] = 0.12)
#    has_hyponym, appoggio, veliero usato per la pesca con lo scafandro.  (Score: 0.00)
#    has_hyponym, bagala, barcone a vela  con la poppa rotonda e la pruna rasa slanciata  in uso nel Mar Rosso e sul Nilo. (Score: 0.00)
#    has_hyponym, baleniera, imbarcazione a remi usata un tempo da comandanti e ammiragli (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, barbariccio, nelle tonnare in Sardegna  la piccola barca a remi in cui prende posto il rais durante la mattanza. (Score: 0.00)
#    has_hyponym, barca, piccola imbarcazione a remi a vela o a motore. (Score: [0.41] * [0.76] = 0.31)
#    has_hyponym, barca_a_vela, No Gloss (Score: 0.00)
#    has_hyponym, barcone, grossa imbarcazione a fondo piatto usata per il trasporto delle merci. (Score: [0.74] * [0.76] = 0.56)
#    has_hyponym, battello, piccola imbarcazione impiegata a servizio di bordo o di porto. (Score: [0.13] * [0.76] = 0.10)
#    has_hyponym, caicco, battello a remi  leggero e sottile  usato sul Bosforo per il trasporto delle persone. E' la gondola del Bosforo. (Score: 0.00)
#    has_hyponym, caiaco, canotto per una persona  fatto di pelli di foca cucite insieme e tese su una intelaiatura di legno  usato dagli Eschimesi per la caccia. (Score: 0.00)
#    has_hyponym, carboniere, piccolo bastimento per il trasporto del carbone.  (Score: 0.00)
#    has_hyponym, cruiser, imbarcazione a motore adatta per piccole crociere (Score: 0.00)
#    has_hyponym, entrobordo, No Gloss (Score: 0.00)
#    has_hyponym, fasello, antica imbarcazione veloce (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, fuoribordo, No Gloss (Score: 0.00)
#    has_hyponym, gondola, No Gloss (Score: 0.00)
#    has_hyponym, house_boat, No Gloss (Score: 0.00)
#    has_hyponym, idroplano, natante a sostentazione idroplana (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, idroscivolante, imbarcazione propulsa con elica aerea (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, iole, piccola imbarcazione a remi o a vela per uso costiero. (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, ketch, No Gloss (Score: 0.00)
#    has_hyponym, lancia, imbarcazione a remi leggera e veloce. (Score: 0.00)
#    has_hyponym, motorsailer, imbarcazione da diporto a vela dotata di un potente motore (Score: 0.00)
#    has_hyponym, motoscafo, imbarcazione spinta da motore a scoppio. (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, nave_da_pesca, imbarcazione o nave attrezzata per la pesca. (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, yacht, No Gloss (Score: 0.00)
#    has_hyponym, patino, imbarcazione da diporto  a remi o pedali (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, pilotina, No Gloss (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, piroga, No Gloss (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, saccoleva, piccolo veloce bastimento  da 30-60 ton.  con saccoleva  trinchetto quadro  e uno o due fiocchi. Usato nell'Arcipelago greco. (Score: 0.00)
#    has_hyponym, sampang, imbarcazione a remi  usata su fiumi e acque costiere nell'Estremo Oriente. (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, sandolino, No Gloss (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, schifo, imbarcazione lunga e stretta  a vela o a remi  usata per la pesca costiera. (Score: 0.00)
#    has_hyponym, singolo, imbarcazione da regata per un solo vogatore. (Score: 0.00)
#    has_hyponym, skiff, No Gloss (Score: 0.00)
#    has_hyponym, soling, No Gloss (Score: 0.00)
#    has_hyponym, tender, imbarcazione di servizio utilizzato per scendere a terra da imbarcazioni più grandi.  (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, thalac, piccolo bastimento indiano. (Score: 0.00)
#    has_hyponym, tiunia, battello piatto  senza chiglia  di origine cinese  usato in Malesia. (Score: 0.00)
#    has_hyponym, topo, barchetta chioggiotta con la quale i pescatori trasportano il pesce ai luoghi di destinazione  a fondo piatto  con murate quasi verticali nella parte centrale e con prua slanciata. (Score: 0.00)
#    has_hyponym, trabaccolo, piccolo bastimento mercantile da carico  a 2 alberi verticali con vele  è in uso nell'Adriatico. (Score: 0.00)
#    has_hyponym, trambai, vaporetto in sevizio in Venezia e nei dintorni. Vocabolo introdotto sul finire del XIX secolo. (Score: 0.00)
#    has_hyponym, tramoggia, grossa barca in ferro con camere d'aria e con 2-4 porte nella carena. (Score: 0.00)
#    has_hyponym, trimarano, veloce imbarcazione a vela o a motore  simile al catamarano. (Score: [0.08] * [0.76] = 0.06)
#    has_hyponym, yawl, imbarcazione a vela da crociera e da regata. (Score: 0.00)
#
# Literal Lemma: oggetto
# MariTerm Gloss: qualunque oggetto concreto
# ItalWN Gloss: oggetto materiale  concreto
# MariTerm ID: N#645
# ItalWN ID: N#4716
# MariTerm Sense: 1
# ItalWN Sense: 1
# Gloss S. (WM): 0.50
# Total Weighted Relation Similarity: 6.54
#   Bonus: 3.30 (10/12 - bulbo, cilindro, colonna, roba, omaggio, prodotto, salvagente, stanga, struttura, versamento)
#   Malus: -0.66 (2/12 - No Gloss in ItalWN: 1, galleggiante - Missing: relitto)
# Total S.: 9.68
# MariTerm Relations:
#    has_hyponym, bulbo, pesante siluro  normalmente in piombo  collocato il più in basso possibile solidarmente alla chiglia  per aumentare il momento raddrizzante dell'imbarcazione sotto vela.  (Score: [0.00] * [0.76] = 0.00)
#    has_hyponym, cilindro, oggetto a forma di cilndro  tubo (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, colonna, si dice di varie cose verticali di forma allungata. (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, galleggiante, qualsiasi corpo che galleggia sia fissato al fondo come boe o gavitelli  sia mobile come vari tipi d'imbarcazione. (Score: [0.50] * [0.76] = 0.38)
#    has_hyponym, roba, qualunque bene mobile  economicamente utile  destinato alla vendita. (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, omaggio, la cosa donata. (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, prodotto, tutto ciò che gli uomini producono. (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, relitto, qualsiasi oggetto che si trovi in mare alla deriva  sul fondo o sulla costa: "un relitto si è incagliato tra gli scogli".  (Score: 0.00)
#    has_hyponym, salvagente, giubbotto contenente materiale galleggiante da indossare in navigazione. (Score: [0.10] * [0.76] = 0.08)
#    has_hyponym, stanga, barra di materiale vario. (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, struttura, cosa costruita (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, versamento, l'oggetto o i valori depositati. (Score: [1.00] * [0.76] = 0.76)
# ItalWN Relations:
#    has_hyperonym, ente, ciò che esiste (Score: 0.00)
#    has_hyponym, acquisizione, la cosa acquisita (Score: 0.00)
#    has_hyponym, affisso, Serramento di vario materiale che serve come chiusura (porte  finestre) nelle strutture murarie. (Score: 0.00)
#    has_hyponym, aggiuntatura, No Gloss (Score: 0.00)
#    has_hyponym, aggregato, massa composita  quantità di materia che si presenta o si considera come un insieme indistinto. (Score: 0.00)
#    has_hyponym, amaca, oggetto usato come giaciglio pensile (Score: 0.00)
#    has_hyponym, ammennicolo, cosa  oggetto di poco conto di cui non si sa ben definire l'uso (Score: 0.00)
#    has_hyponym, amore, l'oggetto dell'amore  predilezione. (Score: 0.00)
#    has_hyponym, anaglipto, oggetto cesellato o decorato in rilievo. (Score: 0.00)
#    has_hyponym, ancora, denominazione di oggetti o parti di macchine che ricordano un'ancora per la forma o per la funzione. (Score: 0.00)
#    has_hyponym, anello, oggetto di forma circolare o affine  o elemento di forma circolare in un oggetto. (Score: 0.00)
#    has_hyponym, anticaglia, oggetto vecchio  fuori moda. (Score: 0.00)
#    has_hyponym, antichità, oggetto antico. (Score: 0.00)
#    has_hyponym, antiquariato, No Gloss (Score: 0.00)
#    has_hyponym, apparizione, la cosa che appare (Score: 0.00)
#    has_hyponym, appoggio, qualunque oggetto che ha la funzione di sostenere o rialzare qualcosa. (Score: 0.00)
#    has_hyponym, arco, qualunque oggetto che abbia la forma curva tipica dell'arco. (Score: 0.00)
#    has_hyponym, asse, tavola  asse rettangolare di legno. (Score: 0.00)
#    has_hyponym, bastone, ramo d'albero lavorato usato come appoggio o arma. (Score: 0.00)
#    has_hyponym, battente, oggetto a forma di martello che batte su una superficie (Score: 0.00)
#    has_hyponym, bersaglio, oggetto da colpire con armi (Score: 0.00)
#    has_hyponym, bicuneo, No Gloss (Score: 0.00)
#    has_hyponym, bioccolo, No Gloss (Score: 0.00)
#    has_hyponym, blocco, un oggetto solido avente una forma rettagolare o quadrata (Score: 0.00)
#    has_hyponym, bolide, oggetto dotato di grande velocità  in specie automobile da corsa  (Score: 0.00)
#    has_hyponym, bucchero, No Gloss (Score: 0.00)
#    has_hyponym, budello, intestino  viscere. (Score: 0.00)
#    has_hyponym, bulbo, oggetto a forma di bulbo. (Score: [0.00] * [0.76] = 0.00)
#    has_hyponym, campana, calotta di vetro a forma di campana che si usa per vari scopi (Score: 0.00)
#    has_hyponym, candeliere, No Gloss (Score: 0.00)
#    has_hyponym, cannello, nome di vari oggetti a forma di canna per lo più lunghi e stretti (Score: 0.00)
#    has_hyponym, capsula, involucro  di forma cilindrica o tonda  che ha la funzione di rivestire  proteggere o contenere. (Score: 0.00)
#    has_hyponym, carabattola, cose inutili e di scarso o nessun valore.  (Score: 0.00)
#    has_hyponym, casalingo, oggetto per la casa  (Score: 0.00)
#    has_hyponym, catena, oggetto costituito da numerosi anelli legati insieme (Score: 0.00)
#    has_hyponym, cerchio, No Gloss (Score: 0.00)
#    has_hyponym, chicco, No Gloss (Score: 0.00)
#    has_hyponym, chiodo, sottile barretta di ferro a sezione circolare con una estremità appuntita e una allargata a forma di capocchia. (Score: 0.00)
#    has_hyponym, ciabatta, si dice di cosa brutta  inservibile. (Score: 0.00)
#    has_hyponym, ciambella, qualunque oggetto di forma circolare con un buco centrale. (Score: 0.00)
#    has_hyponym, cilindro, oggetto a forma di cilndro  tubo (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, cimelio, No Gloss (Score: 0.00)
#    has_hyponym, civetta, oggetto che seve ad attirare l'attenzione (Score: 0.00)
#    has_hyponym, coccio, oggetto rotto  a pezzi (Score: 0.00)
#    has_hyponym, colonna, si dice di varie cose verticali di forma allungata. (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, confort, ciò che dà agio alla vita (Score: 0.00)
#    has_hyponym, cono, qualsiasi oggetto a forma di cono (Score: 0.00)
#    has_hyponym, contenuto, cosa contenuta (Score: 0.00)
#    has_hyponym, contromarca, gettone o biglietto che permette di rientrare nei locali pubblici dopo una breve assenza e di ritirare gli oggetti depositati al guardaroba (Score: 0.00)
#    has_hyponym, coppiglia, elemento metallico che inserito in una vite ne impedisce lo svitamento (Score: 0.00)
#    has_hyponym, cordone, si dice di varie cose in forma di corda. (Score: 0.00)
#    has_hyponym, corno, oggetto a forma di corno (Score: 0.00)
#    has_hyponym, corona, si dice di vari oggetti a forma di corona. (Score: 0.00)
#    has_hyponym, corpo, ogni oggetto che occupi uno spazio  (Score: 0.00)
#    has_hyponym, correttivo, ciò che serve a correggere (Score: 0.00)
#    has_hyponym, cortina, No Gloss (Score: 0.00)
#    has_hyponym, coso, No Gloss (Score: 0.00)
#    has_hyponym, creazione, cosa creata (Score: 0.00)
#    has_hyponym, crociera, oggetto formato da elementi che si intersecano (Score: 0.00)
#    has_hyponym, cubetto, No Gloss (Score: 0.00)
#    has_hyponym, cucito, No Gloss (Score: 0.00)
#    has_hyponym, cucitura, No Gloss (Score: 0.00)
#    has_hyponym, cupolino, No Gloss (Score: 0.00)
#    has_hyponym, cuscinetto, oggetto simile ad un cuscino (Score: 0.00)
#    has_hyponym, dado, No Gloss (Score: 0.00)
#    has_hyponym, danaro, il denaro come oggetto  mezzo di scambio  il denaro come mezzo di scambio (Score: 0.00)
#    has_hyponym, decoro, la cosa che serve ad ornare (Score: 0.00)
#    has_hyponym, dente, oggetto a forma di dente (Score: 0.00)
#    has_hyponym, disco, qualunque oggetto o figura circolare a facce piane. (Score: 0.00)
#    has_hyponym, disco_volante, No Gloss (Score: 0.00)
#    has_hyponym, discoide, No Gloss (Score: 0.00)
#    has_hyponym, ditale, oggetto di metallo o altro materiale  che serve per proteggere la prima falange del dito che spinge l'ago (Score: 0.00)
#    has_hyponym, dondolo, No Gloss (Score: 0.00)
#    has_hyponym, doppia_copia, copia di un documento (Score: 0.00)
#    has_hyponym, effetto, oggetti  di vestiario e simili. (Score: 0.00)
#    has_hyponym, emanazione, No Gloss (Score: 0.00)
#    has_hyponym, equivalente, cosa o persona che equivale (Score: 0.00)
#    has_hyponym, erogazione, la cosa erogata (Score: 0.00)
#    has_hyponym, esca, No Gloss (Score: 0.00)
#    has_hyponym, esemplare, cosa o persona esemplare per pulizia o onestà (Score: 0.00)
#    has_hyponym, ex_voto, No Gloss (Score: 0.00)
#    has_hyponym, falce, qualunque oggetto a forma di falce. (Score: 0.00)
#    has_hyponym, falso, documento  oggetto falsificato. (Score: 0.00)
#    has_hyponym, fenice, persona o cosa molto rara (Score: 0.00)
#    has_hyponym, fermacarte, No Gloss (Score: 0.00)
#    has_hyponym, fermaglio, No Gloss (Score: 0.00)
#    has_hyponym, fermo, No Gloss (Score: 0.00)
#    has_hyponym, ferramento, No Gloss (Score: 0.00)
#    has_hyponym, ferro, oggetto di ferro. (Score: 0.00)
#    has_hyponym, ferro_di_cavallo, ferro ad arco per gli zoccoli del cavallo (Score: 0.00)
#    has_hyponym, ferrovecchio, cosa o persona vecchia e malandata (Score: 0.00)
#    has_hyponym, feticcio, presso i popoli primitivi  oggetto ritenuto sacro  dotato di poteri soprannaturali (Score: 0.00)
#    has_hyponym, filo, cose a forma di filo (Score: 0.00)
#    has_hyponym, foglio, pezzo di carta  per lo più rettangolare (Score: 0.00)
#    has_hyponym, fondamento, qualsiasi cosa che serva di sostegno a un'altra. (Score: 0.00)
#    has_hyponym, frustolo, No Gloss (Score: 0.00)
#    has_hyponym, fungo, oggetto a forma di fungo (Score: 0.00)
#    has_hyponym, gadget, oggetto piccolo  originale  non sempre utile (Score: 0.00)
#    has_hyponym, galanteria, No Gloss (Score: 0.00)
#    has_hyponym, galla, cosa  oggetto molto leggero (Score: 0.00)
#    has_hyponym, galleggiante, No Gloss (Score: [0.50] * [0.76] = 0.38)
#    has_hyponym, gamba, qualsiasi cosa che per analogia ricordi una gamba. (Score: 0.00)
#    has_hyponym, gemma, No Gloss (Score: 0.00)
#    has_hyponym, ghiottoneria, No Gloss (Score: 0.00)
#    has_hyponym, gioiello, cosa che si ritiene preziosa (fig) (Score: 0.00)
#    has_hyponym, girello, ogni oggetto a forma di cerchietto. (Score: 0.00)
#    has_hyponym, grano, particella di qualcosa (Score: 0.00)
#    has_hyponym, guarnitura, No Gloss (Score: 0.00)
#    has_hyponym, idolo, oggetto o immagine venerata come divinità (Score: 0.00)
#    has_hyponym, incorniciatura, inquadratura in legno o metallo posta intorno a dipinti  specchi  aperture  a scopo decorativo. (Score: 0.00)
#    has_hyponym, ingombro, No Gloss (Score: 0.00)
#    has_hyponym, invio, No Gloss (Score: 0.00)
#    has_hyponym, ispessimento, No Gloss (Score: 0.00)
#    has_hyponym, lacrima, qualsiasi oggetto che ricorda la forma di una lacrima. (Score: 0.00)
#    has_hyponym, largizione, No Gloss (Score: 0.00)
#    has_hyponym, lastra, pezzo di materiale rigido  di poco spessore e in genere rettangolare (Score: 0.00)
#    has_hyponym, legamento, No Gloss (Score: 0.00)
#    has_hyponym, legno, pezzo di legno (Score: 0.00)
#    has_hyponym, lingua, cosa a forma di lingua (Score: 0.00)
#    has_hyponym, linguetta, No Gloss (Score: 0.00)
#    has_hyponym, lungo, No Gloss (Score: 0.00)
#    has_hyponym, macchinetta, nel linguaggio corrente  nome di diversi oggetti di uso comune (Score: 0.00)
#    has_hyponym, macina, No Gloss (Score: 0.00)
#    has_hyponym, maiolica, No Gloss (Score: 0.00)
#    has_hyponym, manifattura, No Gloss (Score: 0.00)
#    has_hyponym, mattonella, No Gloss (Score: 0.00)
#    has_hyponym, mobile, oggetto d'arredamento (Score: 0.00)
#    has_hyponym, molle, ogni cosa morbida e cedevole (Score: 0.00)
#    has_hyponym, moncone, No Gloss (Score: 0.00)
#    has_hyponym, nasello, ferro incastrato nello stipite della porta (Score: 0.00)
#    has_hyponym, ninnolo, No Gloss (Score: 0.00)
#    has_hyponym, obbrobrio, cosa o persona di grande bruttezza (Score: 0.00)
#    has_hyponym, oggetto_naturale, ciò che è presente in natura. (Score: 0.00)
#    has_hyponym, omaggio, la cosa donata. (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, ombra, persona o cosa di cui si veda solo il contorno a causa dell'oscurità. (Score: 0.00)
#    has_hyponym, ombrello, qualsiasi oggetto con la forma o la funzione di un ombrello (Score: 0.00)
#    has_hyponym, orma, traccia  orma  ogni impronta visibile lasciata da qualcosa  indizio (Score: 0.00)
#    has_hyponym, oro, oggetti d'oro. (Score: 0.00)
#    has_hyponym, ovulo, No Gloss (Score: 0.00)
#    has_hyponym, paga, somma versata per pagare  corrispettivo  in denaro o altro  del lavoro svolto (Score: 0.00)
#    has_hyponym, paglia, No Gloss (Score: 0.00)
#    has_hyponym, paio, due cose della medesima specie che sono o si considerano insieme. (Score: 0.00)
#    has_hyponym, pallone, denominazione di oggetti tondeggianti (Score: 0.00)
#    has_hyponym, partizione, No Gloss (Score: 0.00)
#    has_hyponym, patacca, No Gloss (Score: 0.00)
#    has_hyponym, pedana, piano rialzato che isola o innalza dal pavimento (Score: 0.00)
#    has_hyponym, pegno, No Gloss (Score: 0.00)
#    has_hyponym, pellicola, No Gloss (Score: 0.00)
#    has_hyponym, pendaglio, No Gloss (Score: 0.00)
#    has_hyponym, penna, per estens.  oggetto appuntito  estremità. (Score: 0.00)
#    has_hyponym, pennacchio, oggetto  figura a forma di pennacchio (Score: 0.00)
#    has_hyponym, pera, qualsiasi oggetto a forma di pera (Score: 0.00)
#    has_hyponym, peso, spec. l'oggetto di metallo che serve a pesare. (Score: 0.00)
#    has_hyponym, pezzo, qualsiasi oggetto considerato in quanto parte di un altro (Score: 0.00)
#    has_hyponym, piatto, per estens.  qualsiasi oggetto a forma di piatto. (Score: 0.00)
#    has_hyponym, piede, qualsiasi oggetto a forma di piede (Score: 0.00)
#    has_hyponym, piombo, nome di oggetti fatti di piombo (Score: 0.00)
#    has_hyponym, pipa, oggetto di forma simile a una pipa (Score: 0.00)
#    has_hyponym, pomello, No Gloss (Score: 0.00)
#    has_hyponym, ponte, per estensione qualsiasi cosa che serva di collegamento. (Score: 0.00)
#    has_hyponym, portachiavi, oggetto di piccole dimensioni usato per fissare le chiavi (Score: 0.00)
#    has_hyponym, portafortuna, oggetto  spesso un ciondolo  cui si attribuisce il potere di proteggere chi lo porta con sé e di propiziare la sorte  procurando benessere e felicità (Score: 0.00)
#    has_hyponym, posta, insieme di lettere e pacchi che devono essere consegnati dal postino (Score: 0.00)
#    has_hyponym, presina, oggetto di panno con cui si prendono utensili molto caldi (Score: 0.00)
#    has_hyponym, prezioso, oggetto di valore (Score: 0.00)
#    has_hyponym, prodotto, tutto ciò che gli uomini producono (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, proprietà, la cosa posseduta (Score: 0.00)
#    has_hyponym, prosecuzione, parte che segue (Score: 0.00)
#    has_hyponym, punto, per estens.  oggetto o segno piccolissimo o che appaia tale. (Score: 0.00)
#    has_hyponym, quadrato, No Gloss (Score: 0.00)
#    has_hyponym, quadretto, No Gloss (Score: 0.00)
#    has_hyponym, quadro, oggetto di forma simile ad un quadrato (Score: 0.00)
#    has_hyponym, quartultimo, persona o cosa che viene prima del terzultimo. (Score: 0.00)
#    has_hyponym, radiosorgente, oggetto che emette radioonde (Score: 0.00)
#    has_hyponym, recupero, l'oggetto ricuperato. (Score: 0.00)
#    has_hyponym, reperto, No Gloss (Score: 0.00)
#    has_hyponym, replica, cosa rifatta (Score: 0.00)
#    has_hyponym, restauro, la cosa o la parte di una cosa che è stata restaurata (Score: 0.00)
#    has_hyponym, rete, struttura di sostegno per il materasso (Score: 0.00)
#    has_hyponym, riccio, ogni cosa a forma di riccio. (Score: 0.00)
#    has_hyponym, riconoscimento, oggetto dato come ricompensa  qualsiasi cosa che si dà per ricompensare qualcuno (Score: 0.00)
#    has_hyponym, ricostruzione, la cosa ricostruita. (Score: 0.00)
#    has_hyponym, rilievo, cosa scolpita che aggetti da un fondo. (Score: 0.00)
#    has_hyponym, rimanente, Ciò che rimane di qualcosa. (Score: 0.00)
#    has_hyponym, rimpiazzo, persona o cosa che fa da rimpiazzo  da sostituto (Score: 0.00)
#    has_hyponym, rinforzo, tutto ciò che serve a rinforzare (Score: 0.00)
#    has_hyponym, roba, qualunque bene mobile  economicamente utile  destinato alla vendita. (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, rogna, cosa che provoca molestia. (Score: 0.00)
#    has_hyponym, ruota, ogni cosa avente forma circolare. (Score: 0.00)
#    has_hyponym, sacramentale, No Gloss (Score: 0.00)
#    has_hyponym, saldatura, No Gloss (Score: 0.00)
#    has_hyponym, saliente, la cosa o la parte che sporge. (Score: 0.00)
#    has_hyponym, salmeria, No Gloss (Score: 0.00)
#    has_hyponym, salvagente, oggetto galleggiante  di forma e materiali vari  in grado di mantenere a galla una persona. (Score: [0.10] * [0.76] = 0.08)
#    has_hyponym, sbarramento, qualcosa (materiale) che impedisce o intralcia.  ostacolo  impedimento. (Score: 0.00)
#    has_hyponym, scaramanzia, No Gloss (Score: 0.00)
#    has_hyponym, scatola, oggetto  congegno a forma di scatola. (Score: 0.00)
#    has_hyponym, sciccheria, No Gloss (Score: 0.00)
#    has_hyponym, scudo, cosa che serve da protezione (Score: 0.00)
#    has_hyponym, segnapunti, No Gloss (Score: 0.00)
#    has_hyponym, soma, la cosa che esercita un peso. (Score: 0.00)
#    has_hyponym, somministrazione, No Gloss (Score: 0.00)
#    has_hyponym, soprammobile, No Gloss (Score: 0.00)
#    has_hyponym, souvenir, No Gloss (Score: 0.00)
#    has_hyponym, specchio, oggetto da toeletta (Score: 0.00)
#    has_hyponym, spina, No Gloss (Score: 0.00)
#    has_hyponym, spirale, qualunque oggetto o struttura a forma di spirale (Score: 0.00)
#    has_hyponym, spoletta, No Gloss (Score: 0.00)
#    has_hyponym, staffa, qualsiasi attrezzo o dispositivo generico di attacco  sostegno o appoggio.  (Score: 0.00)
#    has_hyponym, stampella, apparecchio ortopedico che si appoggia sotto le ascelle  per camminare senza usare le gambe (Score: 0.00)
#    has_hyponym, stanga, barra di materiale vario. (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, stella, qualunque oggetto a forma di stella. (Score: 0.00)
#    has_hyponym, struttura, cosa costruita (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, sughero, oggetto di sughero. (Score: 0.00)
#    has_hyponym, supporto, materiale su cui vengono registrati i dati da elaborare: supporto cartaceo  magnetico e sim.. (Score: 0.00)
#    has_hyponym, tamburo, No Gloss (Score: 0.00)
#    has_hyponym, tappabuchi, cosa o persona utili per ogni evenienza (Score: 0.00)
#    has_hyponym, tarsia, opera eseguita con la tecnica dell'intarsio. (Score: 0.00)
#    has_hyponym, terzultimo, persona o cosa che viene prima del penultimo. (Score: 0.00)
#    has_hyponym, tesoro, cosa molto stimata ed amata perché bellissima o di gran pregio (Score: 0.00)
#    has_hyponym, tettarella, cappuccio di gomma forato all'estremità  che si applica al biberon. (Score: 0.00)
#    has_hyponym, tondello, No Gloss (Score: 0.00)
#    has_hyponym, trabiccolo, No Gloss (Score: 0.00)
#    has_hyponym, trave, elemento delle costruzioni costituito da un tronco d'albero squadrato o da analoghe strutture in acciaio o cemento armato. (Score: 0.00)
#    has_hyponym, traverso, No Gloss (Score: 0.00)
#    has_hyponym, triangolo, oggetto a forma di triangolo usato per segnalare che la carreggiata è occupata. (Score: 0.00)
#    has_hyponym, trofeo, oggetto appartenuto ad un guerriero vinto di cui il vincitore (Score: 0.00)
#    has_hyponym, tubo, No Gloss (Score: 0.00)
#    has_hyponym, velluto, superficie liscia e morbida come il velluto (Score: 0.00)
#    has_hyponym, versamento, l'oggetto o i valori depositati. (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, vincita, No Gloss (Score: 0.00)
#    has_hyponym, volta, per estens.  nome generico di cose a forma di volta. (Score: 0.00)
#    has_hyponym, zavorra, cosa o persona ingombrante e inutile  di nessun valore (Score: 0.00)
#
# Literal Lemma: scrittura
# MariTerm Gloss: uno scritto che documenta qualcosa e che dà informazioni
# ItalWN Gloss: uno scritto che documenta qualcosa e che dà informazioni
# MariTerm ID: N#251
# ItalWN ID: N#3291
# MariTerm Sense: 4
# ItalWN Sense: 4
# Gloss S. (WM): 1.00
# Total Weighted Relation Similarity: 5.32
#   Bonus: 2.31 (7/10 - dichiarazione, fattura, franchigia, manifesto, nulla_osta, assicurazione, scrittura)
#   Malus: -0.99 (3/10 - No Gloss in ItalWN: 0,  - Missing: documenti d'esportazione, documenti d'imbarco, ordine di consegna)
# Total S.: 7.64
# MariTerm Relations:
#    has_hyponym, dichiarazione, documento con il quale si dichiara (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, documenti d'esportazione, No Gloss (Score: 0.00)
#    has_hyponym, documenti d'imbarco, No Gloss (Score: 0.00)
#    has_hyponym, fattura, documento che prova una vendita (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, franchigia, documento che attesta una franchigia (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, manifesto, documento commerciale  relativo soprattutto ad operazioni portuali e aeroportuali (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, nulla_osta, il documento che attesta il permesso accordato (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, ordine di consegna, No Gloss (Score: 0.00)
#    has_hyponym, assicurazione, documento assicurativo (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, scrittura, documento con rilevanza giuridica (Score: [1.00] * [0.76] = 0.76)
# ItalWN Relations:
#    near_synonym, papiro, No Gloss (Score: 0.00)
#    has_hyperonym, testo, insieme di parole che compongono un discorso o uno scritto (Score: 0.00)
#    has_hyponym, abbonamento, documento che attesta il pagamento globale anticipato e ridotto di un servizio in differita nel tempo (Score: 0.00)
#    has_hyponym, allegato, documento aggiunto a uno scritto  a una pratica etc. (Score: 0.00)
#    has_hyponym, assicurazione, documento assicurativo (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, attestato, No Gloss (Score: 0.00)
#    has_hyponym, avallo, documento  scrittura con cui si garantisce il pagamento di una cambiale o di un assegno. (Score: 0.00)
#    has_hyponym, bolla_d'accompagnamento, documento che descrive la merce (Score: 0.00)
#    has_hyponym, bond, denominazione generica di azione e obbligazione (Score: 0.00)
#    has_hyponym, brevetto, No Gloss (Score: 0.00)
#    has_hyponym, buono, ordine di pagamento. (Score: 0.00)
#    has_hyponym, carta_di_credito, No Gloss (Score: 0.00)
#    has_hyponym, carta_di_identità, carta d'identità  di riconoscimento. (Score: 0.00)
#    has_hyponym, cartella, foglio recante scritte con varie funzioni (Score: 0.00)
#    has_hyponym, cartellino, documento che lega un atleta a una società per un periodo (Score: 0.00)
#    has_hyponym, chirografo, documento autografo (Score: 0.00)
#    has_hyponym, coupon, documento che si riceve e che attesta l'acquisto di un bene o un servizio (Score: 0.00)
#    has_hyponym, dichiarazione, documento con il quale si dichiara (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, effetto_cambiario, effetto cambiario (Score: 0.00)
#    has_hyponym, fattura, documento che prova una vendita (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, fonte, documento originale (Score: 0.00)
#    has_hyponym, franchigia, documento che attesta una franchigia (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, garanzia, documento che garantisce l'assistenza (Score: 0.00)
#    has_hyponym, inserto, No Gloss (Score: 0.00)
#    has_hyponym, laurea, titolo di studio dottorale e documento che lo attesta (Score: 0.00)
#    has_hyponym, libretto_di_circolazione, No Gloss (Score: 0.00)
#    has_hyponym, libretto_di_lavoro, No Gloss (Score: 0.00)
#    has_hyponym, libretto_universitario, documento (Score: 0.00)
#    has_hyponym, licenza, diploma scolastico (Score: 0.00)
#    has_hyponym, manifesto, documento commerciale  relativo soprattutto ad operazioni portuali e aeroportuali (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, memorandum, documento per ricordare gli estremi di una questione (Score: 0.00)
#    has_hyponym, novero, un elenco di cose  nomi di persone  fatti ecc.  (Score: 0.00)
#    has_hyponym, nulla_osta, il documento che attesta il permesso accordato (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, ordinativo, documento con cui si fa un ordine (Score: 0.00)
#    has_hyponym, pagella, documento su cui sono riportati i voti conseguiti dagli alunni durante l'anno scolastico o agli esami (Score: 0.00)
#    has_hyponym, partita, scrittura contabile (Score: 0.00)
#    has_hyponym, pass, documento che permette di circolare in ambienti che ammettono solo persone autorizzate (Score: 0.00)
#    has_hyponym, passaporto, documento personale che conferisce al cittadino la possibilità di uscire dal territorio nazionale per recarsi all'estero (Score: 0.00)
#    has_hyponym, patente, documento che autorizza alla guida di veicoli a motore. (Score: 0.00)
#    has_hyponym, pezza_d'appoggio, No Gloss (Score: 0.00)
#    has_hyponym, prenotazione, documento che attesta che si è prenotato un oggetto o un servizio (Score: 0.00)
#    has_hyponym, procura, documento con cui si trasferisce ad altri il potere di rappresentanza (Score: 0.00)
#    has_hyponym, protocollo, documento attestante un raggiunto accordo tra stati (Score: 0.00)
#    has_hyponym, questionario, domande scritte su un determinato argomento (Score: 0.00)
#    has_hyponym, registrazione, No Gloss (Score: 0.00)
#    has_hyponym, registro, libro o quaderno in cui si registra qlco.. (Score: 0.00)
#    has_hyponym, resa_dei_conti, documento con cui si fa un rapporto  un resoconto  rendiconto delle spese e delle entrate al termine di un esercizio . (Score: 0.00)
#    has_hyponym, salvacondotto, No Gloss (Score: 0.00)
#    has_hyponym, scartoffia, No Gloss (Score: 0.00)
#    has_hyponym, scrittura, documento con rilevanza giuridica (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, statino, documento per sostenere un esame universitario (Score: 0.00)
#    has_hyponym, stato_civile, documento che certifica tale posizione (Score: 0.00)
#    has_hyponym, statuto, documento che disciplina l'organizzazione e l'attività di una persona giuridica (Score: 0.00)
#    has_hyponym, titolo, documento che comprova un credito nei riguardi del debito pubblico o di enti privati. (Score: 0.00)
#    has_hyponym, trittico, documento doganale (Score: 0.00)
#    has_hyponym, verbale, documento redatto da un pubblico ufficiale o un segretario  con lo scopo di attestare lo svolgimento di un fatto  una dichiarazione e simili. (Score: 0.00)
#
# Literal Lemma: bussola
# MariTerm Gloss: strumento che indica la direzione del punto cardinale nord e permette pertanto di conoscere la direzione di uno spostamento  rispetto a tale punto cardinale
# ItalWN Gloss: strumento che indica la direzione del punto cardinale nord e permette pertanto di conoscere la direzione di uno spostamento  rispetto a tale punto cardinale
# MariTerm ID: N#106
# ItalWN ID: N#20642
# MariTerm Sense: 1
# ItalWN Sense: 1
# Gloss S. (WM): 1.00
# Total Weighted Relation Similarity: 3.86
#   Bonus: 1.65 (5/5 - utensile, bussola da rilevamento, bussola di rotta, bussola giroscopica, bussola magnetica)
#   Malus: 0.00 (0/5 - No Gloss in ItalWN: 0,  - Missing: )
# Total S.: 6.51
# MariTerm Relations:
#    has_hyperonym, utensile, arnese atto all'esecuzione di determinate operazioni proprie di un'arte  di un mestiere o di una tecnica. (Score: [1.00] * [0.82] = 0.82)
#    has_hyponym, bussola da rilevamento, Particolare tipo di bussola magnetica  per "rilevare" cioè per stabilire la direzione di un qualsiasi oggetto rispetto al nord magnetico. (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, bussola di rotta, Bussola principale dell'imbarcazione  normalmente posta davanti al timone. (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, bussola giroscopica, Bussola che funziona indipendentemente dall'azione del magnetismo terrestre e che si basa sul principio del giroscopio. (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, bussola magnetica, Bussola che sfrutta l'effetto del magnetismo terrestre  composta da uno o più aghi magnetici  liberi di ruotare  che si orientano verso il Nord magnetico disponendosi parallelamente ai meridiani magnetici. (Score: [1.00] * [0.76] = 0.76)
# ItalWN Relations:
#    has_hyperonym, utensile, arnese atto all'esecuzione di determinate operazioni proprie di un'arte  di un mestiere o di una tecnica. (Score: [1.00] * [0.82] = 0.82)
#    has_hyponym, bussola da rilevamento, Particolare tipo di bussola magnetica  per "rilevare" cioè per stabilire la direzione di un qualsiasi oggetto rispetto al nord magnetico.  (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, bussola di rotta, Bussola principale dell'imbarcazione  normalmente posta davanti al timone.  (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, bussola giroscopica, Bussola che funziona indipendentemente dall'azione del magnetismo terrestre e che si basa sul principio del giroscopio.  (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, bussola magnetica, Bussola che sfrutta l'effetto del magnetismo terrestre  composta da uno o più aghi magnetici  liberi di ruotare  che si orientano verso il Nord magnetico disponendosi parallelamente ai meridiani magnetici.  (Score: [1.00] * [0.76] = 0.76)
#
# Literal Lemma: navigazione
# MariTerm Gloss: tecnica e pratica che consentono di mantanere una rotta
# ItalWN Gloss: tecnica e pratica che consentono di mantanere una rotta
# MariTerm ID: N#45
# ItalWN ID: N#49711
# MariTerm Sense: 2
# ItalWN Sense: 3
# Gloss S. (WM): 1.00
# Total Weighted Relation Similarity: 3.80
#   Bonus: 1.65 (5/6 - navigazione astronomica, navigazione piana, navigazione stimata, navigazione strumentale, radionavigazione)
#   Malus: -0.33 (1/6 - No Gloss in ItalWN: 0,  - Missing: tecnologia)
# Total S.: 6.12
# MariTerm Relations:
#    has_hyperonym, tecnologia, attività volta a creare congegni e macchinari (Score: 0.00)
#    has_hyponym, navigazione astronomica, insieme dei metodi e degli strumenti per determinare la posizione geografica mediante l'osservazione degli astri e la misurazione delle loro coordinate. (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, navigazione piana, insieme dei metodi e degli espedienti per risolvere i problemi della "navigazione costiera" e della "navigazione stimata" sulla carta nautica con l'ausilio della Geometria Piana. (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, navigazione stimata, procedimento per calcolare e determinare la posizione geografica attuale in dipendenza dell'ultima posizione certa. (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, navigazione strumentale, la navigazione che si avvale dell'ausilio di vari strumenti. (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, radionavigazione, navigazione assistita via radio sia aerea che marittima (Score: [1.00] * [0.76] = 0.76)
# ItalWN Relations:
#    has_hyperonym, mestiere, attività umana che si basa sull'abilità individuale e su un complesso di regole e conoscenze tecniche ad essa necessarie. (Score: 0.00)
#    has_hyponym, navigazione astronomica, insieme dei metodi e degli strumenti per determinare la posizione geografica mediante l'osservazione degli astri e la misurazione delle loro coordinate. (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, navigazione piana, insieme dei metodi e degli espedienti per risolvere i problemi della "navigazione costiera" e della "navigazione stimata" sulla carta nautica con l'ausilio della Geometria Piana. (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, navigazione stimata, procedimento per calcolare e determinare la posizione geografica attuale in dipendenza dell'ultima posizione certa. (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, navigazione strumentale, la navigazione che si avvale dell'ausilio di vari strumenti. (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, radionavigazione, navigazione assistita via radio sia aerea che marittima (Score: [1.00] * [0.76] = 0.76)
#
# Literal Lemma: porto
# MariTerm Gloss: luogo di scalo di navi
# ItalWN Gloss: luogo di scalo di navi
# MariTerm ID: N#90
# ItalWN ID: N#17185
# MariTerm Sense: 1
# ItalWN Sense: 1
# Gloss S. (WM): 1.00
# Total Weighted Relation Similarity: 4.83
#   Bonus: 2.31 (7/14 - scalo, luogo, porto commerciale, porto di rifornimento, porto di velocità, porto industriale, porto petrolifero)
#   Malus: -2.31 (7/14 - No Gloss in ItalWN: 0,  - Missing: porti d'Europa, porto di armamento, porto di scalo, porto di trasbordo, porto feeder, Porto in Toscana, rada)
# Total S.: 5.83
# MariTerm Relations:
#    near_synonym, scalo, luogo in cui arrivano o da cui partono mezzi e passeggeri di aerei  navi  treni (Score: [1.00] * [0.60] = 0.60)
#    has_hyperonym, luogo, parte dello spazio occupata o occupabile materialmente o idealmente (Score: [0.52] * [0.82] = 0.43)
#    has_hyponym, porti d'Europa, No Gloss (Score: 0.00)
#    has_hyponym, porto commerciale, porto dedicato al traffico commerciale e mercantile. (Score: [1.00] * [0.76] = 0.76)
# ...
#    has_hyponym, virare, manovrare in modo che l'imbarcazione o l'aereo cambino direzione. (Score: [0.00] * [0.76] = 0.00)
#
# Literal Lemma: barca
# MariTerm Gloss: imbarcazione di piccole dimensioni  a remi  a vela  o a motore aperta o parzialmente pontata
# ItalWN Gloss: piccola imbarcazione a remi a vela o a motore
# MariTerm ID: N#1
# ItalWN ID: N#12151
# MariTerm Sense: 1
# ItalWN Sense: 1
# Gloss S. (WM): 0.41
# Total Weighted Relation Similarity: 1.47
#   Bonus: 0.66 (2/18 - imbarcazione, canoa)
#   Malus: -5.28 (16/18 - No Gloss in ItalWN: 3, bilancella, burchiello, gozzo - Missing: barbariccio, barca da regata, battana, canara, cangia, caorlina, draffiniera, eiker, gondola, ingerlut, portolata, topo, tramoggia)
# Total S.: -2.74
# MariTerm Relations:
#    has_hyperonym, imbarcazione, termine generico per indicare barche di piccole e medie dimensioni  utilizzate per diversi scopi (lavoro  piacere  etc.).  (Score: [0.18] * [0.82] = 0.14)
#    has_hyponym, barbariccio, piccola barca a remi usata in Sardegna per la pesca dei tonni. (Score: 0.00)
#    has_hyponym, barca da regata, No Gloss (Score: 0.00)
#    has_hyponym, battana, piccola barca a fondo piatto  mossa da un solo remo a due pale. (Score: 0.00)
#    has_hyponym, bilancella, piccola imbarcazione da pesca  usata soprattutto in Sicilia e attrezzata con un albero a vela latina e un fiocco.  (Score: [0.50] * [0.76] = 0.38)
#    has_hyponym, burchiello, piccola barca a fondo piatto pwer trasporti fluviali  lagunari o lacustri. (Score: [0.50] * [0.76] = 0.38)
#    has_hyponym, canara, barca per il trasporto di canne. (Score: 0.00)
#    has_hyponym, cangia, sorta di barca leggera  e vela e a remo  usata in Egitto per viaggiare sul Nilo. (Score: 0.00)
#    has_hyponym, canoa, barca degli Indiani dell’America centrale  scavata in un tronco d’albero  con poppa e prua uguali. (Score: [0.24] * [0.76] = 0.18)
#    has_hyponym, caorlina, barca da pesca caratteristica della laguna veneta. (Score: 0.00)
#    has_hyponym, draffiniera, barca usata per la pesca del pescespada. (Score: 0.00)
#    has_hyponym, eiker, lunga e stretta barca olandese per caricare la torba. (Score: 0.00)
#    has_hyponym, gondola, barca a due remi  e di solito a un sol rematore  sottile  lunga  a fondo piatto  con estremità molto rialzate. Forse dal latino cymbula (barchetta) o concha (concula=conchiglia)  o dal greco kuntelas (dalle parole kontos (corto) e helas (navicella)). (Score: 0.00)
#    has_hyponym, gozzo, barca con la quale i pescatori di tonni fanno la guardia sopra il bordonaro  per osservare quando vengono i tonni. (Score: [0.50] * [0.76] = 0.38)
#    has_hyponym, ingerlut, grande barca groenlandese. (Score: 0.00)
#    has_hyponym, portolata, barca in uso nell'Adriatico per raccogliere il pescato dalle flottiglie che operano al largo. (Score: 0.00)
#    has_hyponym, topo, barchetta chioggiotta con la quale i pescatori trasportano il pesce ai luoghi di destinazione  a fondo piatto  con murate quasi verticali nella parte centrale e con prua slanciata. (Score: 0.00)
#    has_hyponym, tramoggia, grossa barca in ferro con camere d'aria e con 2-4 porte nella carena. (Score: 0.00)
# ItalWN Relations:
#    has_hyperonym, imbarcazione, qualsiasi natante di dimensioni relativamente piccole. (Score: [0.18] * [0.82] = 0.14)
#    has_hyponym, barchetta, No Gloss (Score: 0.00)
#    has_hyponym, bilancella, No Gloss (Score: [0.50] * [0.76] = 0.38)
#    has_hyponym, bissona, No Gloss (Score: 0.00)
#    has_hyponym, bragozzo, No Gloss (Score: 0.00)
#    has_hyponym, burchiello, No Gloss (Score: [0.50] * [0.76] = 0.38)
#    has_hyponym, canoa, barca veloce  lunga e stretta usata per competizioni sportive. (Score: [0.24] * [0.76] = 0.18)
#    has_hyponym, canotto, No Gloss (Score: 0.00)
#    has_hyponym, catamarano, No Gloss (Score: 0.00)
#    has_hyponym, corallina, No Gloss (Score: 0.00)
#    has_hyponym, dinghy, No Gloss (Score: 0.00)
#    has_hyponym, finn, No Gloss (Score: 0.00)
#    has_hyponym, flying_dutchman, No Gloss (Score: 0.00)
#    has_hyponym, gozzo, No Gloss (Score: [0.50] * [0.76] = 0.38)
#    has_hyponym, guscio, barchetta o casa molto piccola (Score: 0.00)
#    has_hyponym, lampara, barca che pesca con la lampara (Score: 0.00)
#    has_hyponym, motobarca, No Gloss (Score: 0.00)
#    has_hyponym, motopeschereccio, No Gloss (Score: 0.00)
#    has_hyponym, palischermo, No Gloss (Score: 0.00)
#    has_hyponym, paranza, No Gloss (Score: 0.00)
#    has_hyponym, sandalo, barca a remi dal fondo piatto (Score: 0.00)
#    has_hyponym, scialuppa, No Gloss (Score: 0.00)
#    has_hyponym, sloop, No Gloss (Score: 0.00)
#    has_hyponym, snipe, imbarcazione a vela da regata  con scafo a spigolo e deriva mobile. (Score: 0.00)
#    has_hyponym, tartana, No Gloss (Score: 0.00)
#
# Literal Lemma: aria
# MariTerm Gloss: spostamento di masse d aria atmosferiche dovuto a differenza di temperatura o di pressione  spostamento di masse d aria atmosferiche causato da differenze di temperatura o di pressione
# ItalWN Gloss: spostamento di masse d aria atmosferiche dovuto a differenza di temperatura o di pressione  spostamento di masse d aria atmosferiche causato da differenze di temperatura o di pressione
# MariTerm ID: N#224
# ItalWN ID: N#5084
# MariTerm Sense: 5
# ItalWN Sense: 5
# Gloss S. (WM): 1.00
# Total Weighted Relation Similarity: 1.17
#   Bonus: 0.33 (1/19 - buffo)
#   Malus: -5.94 (18/19 - No Gloss in ItalWN: 1, fenomeno_atmosferico - Missing: bava di vento, bufera, groppo, raffica, vento a raffiche, vento al traverso, vento apparente, vento contrario, vento costante, vento di prua, vento dominante, vento favorevole, vento in poppa, vento locale, vento portante, vento reale, vento teso)
# Total S.: -3.44
# MariTerm Relations:
#    has_hyperonym, fenomeno_atmosferico, fenomeno fisico che concerne l'atmosfera. (Score: [0.50] * [0.82] = 0.41)
#    has_hyponym, bava di vento, vento debolissimo e instabile. (Score: 0.00)
#    has_hyponym, bufera, forte vento a raffiche  con neve  pioggia o grandine. (Score: 0.00)
#    has_hyponym, groppo, Violenta ed improvvisa raffica di vento  di breve durata (Score: 0.00)
#    has_hyponym, raffica, improvviso colpo di vento  di breve durata. (Score: 0.00)
#    has_hyponym, buffo, vento leggero che soffia a tratti (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, vento a raffiche, vento caratterizzato da continui cambi di direzione e di intensità. (Score: 0.00)
#    has_hyponym, vento al traverso, vento proveniente dalla direzione perpendicolare alla chiglia dell'imbarcazione. E' il vento che consente di sviluppare la massima velocità a vela. (Score: 0.00)
#    has_hyponym, vento apparente, vento che investe una imbarcazione in movimento  ed è la somma del vento reale e del vento di velocità (cioè del vento creato dal veliero nel suo spostamento). (Score: 0.00)
#    has_hyponym, vento contrario, vento che proviene dalla direzione opposta a quella della rotta. (Score: 0.00)
#    has_hyponym, vento costante, vento che mantiene inalterata la direzione di provenienza e l'intensità. (Score: 0.00)
#    has_hyponym, vento di prua, vento contrario o proveniente da una direzione prossima alla prua  che consente la navigazione di bolina. (Score: 0.00)
#    has_hyponym, vento dominante, vento che in una determinata zona soffia più frequentemente con una certa intensità. (Score: 0.00)
#    has_hyponym, vento favorevole, vento che proviene da una direzione tale da poter essere sfruttato dalla velatura in dipendenza dalla rotta da seguire. (Score: 0.00)
#    has_hyponym, vento in poppa, vento portante proveniente da una direzione vicina alla poppa  che consente di navigare in "fil di ruota". (Score: 0.00)
#    has_hyponym, vento locale, i venti locali compiono solo brevi percorsi e si ripetono con una certa frequenza nelle stesse località. (Score: 0.00)
#    has_hyponym, vento portante, vento che proviene da poppavia (fino al traverso) e che quindi spinge l'imbarcazione. (Score: 0.00)
#    has_hyponym, vento reale, vento detto anche atmosferico  è quello che si può misurare quando si è fermi (sulla costa  ancorati  etc.). (Score: 0.00)
#    has_hyponym, vento teso, vento ideale per far correre un veliero di dimensioni importanti. (Score: 0.00)
# ItalWN Relations:
#    has_hyperonym, fenomeno_atmosferico, No Gloss (Score: [0.50] * [0.82] = 0.41)
#    has_hyponym, aliseo, vento costante che spira tutto l'anno tra i due tropici e l'equatore (Score: 0.00)
#    has_hyponym, aura, vento leggero e piacevole (Score: 0.00)
#    has_hyponym, bora, vento di nord-est che durante l'inverno spira sull'Adriatico (Score: 0.00)
#    has_hyponym, borino, vento estivo dell'alto Adriatico. (Score: 0.00)
#    has_hyponym, breva, vento periodico tipico dei laghi lombardi (Score: 0.00)
#    has_hyponym, brezza, vento tipico delle coste che spira mattina e sera in direzioni opposte (Score: 0.00)
#    has_hyponym, buffo, vento leggero che soffia a tratti (Score: [1.00] * [0.76] = 0.76)
#    has_hyponym, colpo_di_vento, improvviso e violento colpo di vento. (Score: 0.00)
#    has_hyponym, contraliseo, No Gloss (Score: 0.00)
#    has_hyponym, controaliseo, vento che spira al di sopra dell'aliso (Score: 0.00)
#    has_hyponym, favonio, vento caldo  secco  delle vallate alpine (Score: 0.00)
#    has_hyponym, filo_d'aria, soffio leggero di vento (Score: 0.00)
#    has_hyponym, garbino, vento di libeccio  vento caldo che proviene da sud-ovest (Score: 0.00)
#    has_hyponym, ghibli, vento caldo e secco che soffia sull'Africa settentrionale (Score: 0.00)
#    has_hyponym, grecale, vento di nord-est (Score: 0.00)
#    has_hyponym, libecciata, vento di libeccio (Score: 0.00)
#    has_hyponym, maestrale, vento di nord-ovest che proviene dall'Atlantico e soffia sul Mediterraneo occidentale. (Score: 0.00)
#    has_hyponym, mistral, vento tipico di alcune zone della Francia (Score: 0.00)
#    has_hyponym, monsone, vento periodico caldo e umido (Score: 0.00)
#    has_hyponym, ostro, vento umido e caldo proveniente da Sud (Score: 0.00)
#    has_hyponym, ponente, il vento che spira da occidente (Score: 0.00)
#    has_hyponym, scirocco, vento caldo che soffia da sud-est. (Score: 0.00)
#    has_hyponym, simun, vento caldo e secco (Score: 0.00)
#    has_hyponym, tramontana, vento gelido del nord. (Score: 0.00)
#    has_hyponym, traversia, vento che spira perpendicolarmente alla rotta di una nave. (Score: 0.00)
#    has_hyponym, zefiro, vento leggero e piacevole (Score: 0.00)
#
# Literal Lemma: bandiera
# MariTerm Gloss: drappo di stoffa leggera attaccata all asta o all albero di una nave
# ItalWN Gloss: gioco di bimbi con lo scopo di conquistare una bandiera
# MariTerm ID: N#98
# ItalWN ID: N#26277
# MariTerm Sense: 1
# ItalWN Sense: 2
# Gloss S. (WM): 0.22
# Total Weighted Relation Similarity: 0.00
#   Bonus: 0.00 (0/14 - )
#   Malus: -4.62 (14/14 - No Gloss in ItalWN: 0,  - Missing: bandiera del proprietario, bandiera di bompresso, bandiera di classe, bandiera di cortesia, bandiera di quarantena, bandiera in derno, bandiera mercantile, bandiera militare, bandiera nazionale, bandiera ombra, bandiera parlamentare, distintivo, guidone, intelligenza)
# Total S.: -4.40
# MariTerm Relations:
#    has_hyponym, bandiera del proprietario, bandiera normalmente di piccolo formato con colori e disegno personale dell'armatore. (Score: 0.00)
#    has_hyponym, bandiera di bompresso, bandiera quadrata alzata a prua dalle navi da guerra all'ormeggio. (Score: 0.00)
#    has_hyponym, bandiera di classe, bandiera diversa per ogni classe di regata  usata dalla giuria per i segnali di avviso. (Score: 0.00)
#    has_hyponym, bandiera di cortesia, bandiera di uno stato estero che si alza a dritta dell'albero di prora entrando in un porto di tale stato. (Score: 0.00)
#    has_hyponym, bandiera di quarantena, bandiera che indica malati contagiosi a bordo. (Score: 0.00)
#    has_hyponym, bandiera in derno, bandiera con il battente annodato  che indica disgrazia a bordo o richiesta urgente d'aiuto.  (Score: 0.00)
#    has_hyponym, bandiera mercantile, emblema di nazionalità delle navi mercantili  talora diversa da quella nazionale e militare. (Score: 0.00)
#    has_hyponym, bandiera militare, emblema di nazionalità delle navi militari  talora diversa da quella nazionale. (Score: 0.00)
#    has_hyponym, bandiera nazionale, bandiera del proprio Paese o di quello in cui è stata immatricolata l'imbarcazione. (Score: 0.00)
#    has_hyponym, bandiera ombra, bandiera straniera di una nave regolarmente immatricolata all'estero  ma in sostanza di proprietà di cittadini o società nazionali. (Score: 0.00)
#    has_hyponym, bandiera parlamentare, bandiera bianca alzata in guerra da una nave che voglia avvicinare navi nemiche per trattare. (Score: 0.00)
#    has_hyponym, distintivo, bandiera con particolari funzioni di segnalazione. (Score: 0.00)
#    has_hyponym, guidone, bandiera di forma triangolare o di striscia  che rappresenta il club di appartenenza o la compagnia di navigazione nella navi della Marina Mercantile.  (Score: 0.00)
#    has_hyponym, intelligenza, bandiera di segnalazione per richiamare l'attenzione ed esporre successivamente una ulteriore segnalazione. Si utilizza anche per rispondere "ho capito". (Score: 0.00)
# ItalWN Relations:
#    has_hyperonym, gioco, i passatempi  le attività ricreative (Score: 0.00)
#
# Literal Lemma: annodatura
# MariTerm Gloss: legamento di due estremità di funi  cavi e sim
# ItalWN Gloss: legamento di due estremità di funi  nastri e sim
# MariTerm ID: N#389
# ItalWN ID: N#9235
# MariTerm Sense: 1
# ItalWN Sense: 1
# Gloss S. (WM): 0.82
# Total Weighted Relation Similarity: 0.00
#   Bonus: 0.00 (0/26 - )
#   Malus: -8.58 (26/26 - No Gloss in ItalWN: 0,  - Missing: cappio del pescatore, gassa d'amante, gassa d'amante semplice, gassa spagnola, impalmatura, mezzocollo, nodo d'anguilla, nodo del barcaiolo, nodo del cappuccino, nodo del francescano, nodo dell'impiccato, nodo di ancorotto ganciato, nodo di bolina, nodo di bozza, nodo bandiera, nodo inglese, nodo margherita, nodo parlato semplice, nodo piano, nodo portoghese, nodo Savoia, nodo scorsoio semplice, nodo semplice, nodo vaccaio, nodo volante, pugno di scimmia)
# Total S.: -7.76
# MariTerm Relations:
#    has_hyponym, cappio del pescatore, No Gloss (Score: 0.00)
#    has_hyponym, gassa d'amante, il nodo più comunemente utilizzato nella marineria  ed è formato da un'occhio serrato da un nodo.   (Score: 0.00)
#    has_hyponym, gassa d'amante semplice, No Gloss (Score: 0.00)
#    has_hyponym, gassa spagnola, No Gloss (Score: 0.00)
#    has_hyponym, impalmatura, legatura con spago fine che si esegue alle estremità di una cima per impedire che si scordoni o si apra.   (Score: 0.00)
#    has_hyponym, mezzocollo, No Gloss (Score: 0.00)
#    has_hyponym, nodo d'anguilla, No Gloss (Score: 0.00)
#    has_hyponym, nodo del barcaiolo, No Gloss (Score: 0.00)
#    has_hyponym, nodo del cappuccino, No Gloss (Score: 0.00)
#    has_hyponym, nodo del francescano, No Gloss (Score: 0.00)
#    has_hyponym, nodo dell'impiccato, No Gloss (Score: 0.00)
#    has_hyponym, nodo di ancorotto ganciato, No Gloss (Score: 0.00)
#    has_hyponym, nodo di bolina, nodo scorsoio  per stringere ciò che abbranca. (Score: 0.00)
#    has_hyponym, nodo di bozza, No Gloss (Score: 0.00)
#    has_hyponym, nodo bandiera, nodo per unire la bandiera all'alabbasso e alla drizza quando manchino i ganci. (Score: 0.00)
#    has_hyponym, nodo inglese, No Gloss (Score: 0.00)
#    has_hyponym, nodo margherita, No Gloss (Score: 0.00)
#    has_hyponym, nodo parlato semplice, No Gloss (Score: 0.00)
#    has_hyponym, nodo piano, No Gloss (Score: 0.00)
#    has_hyponym, nodo portoghese, No Gloss (Score: 0.00)
#    has_hyponym, nodo Savoia, No Gloss (Score: 0.00)
#    has_hyponym, nodo scorsoio semplice, No Gloss (Score: 0.00)
#    has_hyponym, nodo semplice, termine generico per indicare le legature tra due cime o corde che  nella marineria  sono realizzate in base ai particolari usi ai quali sono destinate.   (Score: 0.00)
#    has_hyponym, nodo vaccaio, No Gloss (Score: 0.00)
#    has_hyponym, nodo volante, No Gloss (Score: 0.00)
#    has_hyponym, pugno di scimmia, No Gloss (Score: 0.00)
# ItalWN Relations:
#    has_hyperonym, legamento, No Gloss (Score: 0.00)
#    has_hyponym, nodo_scorsoio, No Gloss (Score: 0.00)

# %%
def format_results(MariT, ItalWN, breakdown_csv):
    unique_entries = save_entries(MariT, ItalWN, breakdown_csv)

    if not unique_entries:
        print("No entries found. Exiting.")
        return []

    total_similarities = [entry['Total S.'] for entry in unique_entries]
    min_similarity = min(total_similarities)
    max_similarity = max(total_similarities)

    unique_entries.sort(key=lambda x: x['Total S.'], reverse=True)

    formatted_results = []

    for entry in unique_entries:
        literal_lemma = entry.get('Literal Lemma', 'N/A')
        mari_term_id = entry.get('Mariterm ID', 'N/A')
        mari_t_sense = entry.get('MariT sense', 'N/A')
        iwn_sense = entry.get('IWN sense', 'N/A')
        wn_g_sim = entry.get("Gloss S. (WM)", 0.0)
        total_similarity = entry.get('Total S.', 0.00)
        total_weighted_similarity = entry.get('T. Relation S.', 0.00)
        malus = entry.get('Malus', 0.00)  # Ensure the 'Malus' value is retrieved correctly
        bonus = entry.get('Bonus', 0.00)  # Ensure the 'Bonus' value is retrieved correctly
        gloss = entry.get('Mariterm Gloss', 'No Gloss Available')

        formatted_results.append({
            'Literal Lemma': literal_lemma,
            'MariTerm ID': mari_term_id,
            'MariT sense': mari_t_sense,
            'IWN sense': iwn_sense,
            'Gloss S. (WM)': wn_g_sim,
            'Total S.': total_similarity,
            'T. Relation S.': total_weighted_similarity,
            'Malus': malus,  # Correctly reference 'Malus' key
            'Bonus': bonus,  # Correctly reference 'Bonus' key
            'MariTerm Gloss': gloss,
        })

    return formatted_results

def print_formatted_results(formatted_results):
    if not formatted_results:
        print("No valid entries to display.")
        return

    print(f"{'Literal Lemma':<25} {'MariTerm ID':<15} {'MariT sense':<12} {'IWN sense':<12} {'Gloss S. (WM)':<15} {'Total S.':<15} {'T. Relation S.':<20} {'Malus':<10} {'Bonus':<10} {'MariTerm Gloss':<50}")
    print('-' * 250)

    for result in formatted_results:
        print(f"{result['Literal Lemma']:<25} {result['MariTerm ID']:<15} {result['MariT sense']:<12} {result['IWN sense']:<12} "
              f"{result['Gloss S. (WM)']:<15.2f} {result['Total S.']:<15.2f} {result['T. Relation S.']:<20.2f}"
              f"{result['Malus']:<10.2f} {result['Bonus']:<10.2f} {result['MariTerm Gloss']:<50}")

def store_to_csv(formatted_results, breakdown_csv):
    # Entries with "[FALLBACK]" glosses have already had the gloss removed during the formatting step
    df = pd.DataFrame(formatted_results)

    if 'Gloss S. (WM)' in df.columns:
        df['Gloss S. (WM)'] = pd.to_numeric(df['Gloss S. (WM)'], errors='coerce')
    else:
        print("Warning: 'Gloss S. (WM)' column is missing!")
    
    df['Malus'] = pd.to_numeric(df['Malus'], errors='coerce')
    df['Bonus'] = pd.to_numeric(df['Bonus'], errors='coerce')

    required_columns = ['Literal Lemma', 'MariTerm ID', 'MariT sense', 'IWN sense', 'Gloss S. (WM)', 'Total S.', 'T. Relation S.', 'Malus', 'Bonus', 'MariTerm Gloss']
    for col in required_columns:
        if col not in df.columns:
            raise ValueError(f"Missing required column: {col}")
        
    df.to_csv(breakdown_csv, sep=';', encoding='utf-8', index=False, float_format='%.2f')


# Main Execution
formatted_results = format_results(MariT, ItalWN, candidates_csv)
if formatted_results:
    print_formatted_results(formatted_results)
    store_to_csv(formatted_results, breakdown_csv)
else:
    print("No results were generated.")

# %%
# Function to validate XML
def validate_xml(file_path):
    try:
        ET.parse(file_path)
        return True
    except ET.ParseError as e:
        print(f"Error parsing {file_path}: {e}")
        return False

# Filter meanings based on lemmas and senses
def filter_wm(xml_root):
    word_meanings = []
    for word_meaning in xml_root.findall(".//WORD_MEANING"):
        lemma_variants = word_meaning.find("VARIANTS")
        lemmas = [literal.get("LEMMA") for literal in lemma_variants.findall("LITERAL") if literal.get("LEMMA")]
        senses = [literal.get("SENSE") for literal in lemma_variants.findall("LITERAL") if literal.get("SENSE")]
        first_literal = lemma_variants.find("LITERAL")
        first_literal_lemma = first_literal.get("LEMMA") if first_literal is not None else "No Literal Lemma"
        first_literal_sense = first_literal.get("SENSE") if first_literal is not None else "No Sense"
        
        word_meanings.append({
            "id": word_meaning.get("ID"),
            "lemmas": lemmas,
            "senses": senses,
            "first_literal_lemma": first_literal_lemma,
            "first_literal_sense": first_literal_sense,
            "original_element": word_meaning
        })

    return word_meanings

# Match lemmas based on first literal lemma and sense numbers from the CSV
def match_lemmas(mari_term_wms, ital_wn_wms, csv_entries):
    matched_pairs = []
    for entry in csv_entries:
        csv_lemma = entry['literal_lemma'].lower()
        mari_t_sense = entry['mari_t_sense']
        iwn_sense = entry['iwn_sense']
        
        # Find the correct word meanings based on both the lemma and the sense numbers
        mari_match = next((wm for wm in mari_term_wms if wm["first_literal_lemma"].lower() == csv_lemma and wm["first_literal_sense"] == mari_t_sense), None)
        iwn_match = next((wm for wm in ital_wn_wms if wm["first_literal_lemma"].lower() == csv_lemma and wm["first_literal_sense"] == iwn_sense), None)
        
        if mari_match and iwn_match:
            matched_pairs.append((mari_match["original_element"], iwn_match["original_element"]))
        else:
            print(f"Skipped: Could not find matching sense for {csv_lemma} (MariTerm sense {mari_t_sense}, IWN sense {iwn_sense})")

    return matched_pairs

# Transcribe matched pairs to new XML files
def transcribe_matched_pairs(matched_pairs, filt_mart, filt_iwn):
    mari_term_root = ET.Element("WN")
    ital_wn_root = ET.Element("WN")
    
    for mari_element, ital_element in matched_pairs:
        mari_term_root.append(mari_element)
        ital_wn_root.append(ital_element)
    
    mari_term_tree = ET.ElementTree(mari_term_root)
    mari_term_tree.write(filt_mart, encoding="utf-8", xml_declaration=True)
    
    ital_wn_tree = ET.ElementTree(ital_wn_root)
    ital_wn_tree.write(filt_iwn, encoding="utf-8", xml_declaration=True)

# Main function to process and transcribe candidate entries
def transcribe_candidates(MariT, ItalWN, candidates_file, filt_mart, filt_iwn):
    if not validate_xml(MariT) or not validate_xml(ItalWN):
        return
    
    mari_term_wms = filter_wm(ET.parse(MariT).getroot())
    ital_wn_wms = filter_wm(ET.parse(ItalWN).getroot())
    
    # Read the CSV file to extract the lemmas and their corresponding senses
    csv_entries = []
    with open(candidates_file, mode='r', newline='', encoding='utf-8') as csvfile:
        reader = csv.DictReader(csvfile, delimiter=';')
        for row in reader:
            csv_entries.append({
                'literal_lemma': row['Literal Lemma'],
                'mari_t_sense': row.get('MariT sense', 'N/A'),
                'iwn_sense': row.get('IWN sense', 'N/A')
            })
    
    matched_pairs = match_lemmas(mari_term_wms, ital_wn_wms, csv_entries)
    transcribe_matched_pairs(matched_pairs, filt_mart, filt_iwn)
    print(f"Total matched pairs transcribed: {len(matched_pairs)}")

# Process and transcribe candidates
transcribe_candidates(MariT, ItalWN, breakdown_csv, filt_mart, filt_iwn)

# %% [markdown]
# # Parte 2
# Allineamento - aggiornamento delle voci

# %%
replaced_glosses = []
new_word_meanings = []

def read_lemmas_from_csv(file_path):
    lemmas = []
    with open(file_path, mode='r', newline='', encoding='utf-8') as csvfile:
        reader = csv.DictReader(csvfile, delimiter=';')
        for row in reader:
            gloss_similarity = float(row['Gloss S. (WM)'])
            total_weighted_similarity = float(row['T. Relation S.'])
            total_similarity = float(row['Total S.'])
            malus = float(row['Malus'])
            literal_lemma = row['Literal Lemma']
            mari_t_sense = row.get('MariT sense', 'N/A')
            iwn_sense = row.get('IWN sense', 'N/A')

            if gloss_similarity >= 0.43 or total_weighted_similarity > 0.00:
                lemmas.append({'literal_lemma': literal_lemma, 'mari_t_sense': mari_t_sense, 'iwn_sense': iwn_sense})
            elif gloss_similarity == 0 or malus == 0:
                print(f"Skipped - G.Sim (WM) or Malus = 0: {literal_lemma} | MariTerm Sense: {mari_t_sense} | ItalWN Sense: {iwn_sense}")
            else:
                if mari_t_sense == iwn_sense:
                    if (
                        (0.29 <= gloss_similarity < 0.42 and (-0.03 <= total_similarity or total_similarity <= -0.35)) or
                        (0.16 < gloss_similarity < 0.29 and (malus == -0.33 or total_similarity >= -0.42)) or
                        (0.13 <= gloss_similarity <= 0.16 and (-0.83 <= total_similarity <= -0.20)) or
                        (0.10 <= gloss_similarity <= 0.12 and total_similarity >= -0.55) or
                        (0.06 <= gloss_similarity <= 0.09 and (-0.60 <= total_similarity <= -0.26)) or
                        (0 < gloss_similarity <= 0.05 and (-0.61 <= total_similarity <= -0.28))
                    ):
                        lemmas.append({'literal_lemma': literal_lemma, 'mari_t_sense': mari_t_sense, 'iwn_sense': iwn_sense})
                else:
                    if (
                        (0.29 < gloss_similarity < 0.42 and total_similarity >= -0.02) or
                        (0.25 <= gloss_similarity < 0.28 and total_similarity >= -1.07) or
                        (0.19 <= gloss_similarity <= 0.24 and (-4.40 < total_similarity < -0.11 or total_similarity >= -0.76)) or
                        (0.16 <= gloss_similarity <= 0.18 and total_similarity >= -1.14) or
                        (0.13 <= gloss_similarity <= 0.15 and -1.52 <= total_similarity < -0.18) or
                        (0.10 <= gloss_similarity < 0.12 and (total_similarity >= -0.55 or total_similarity == -0.89)) or
                        (0.07 < gloss_similarity <= 0.09 and (-2.55 <= total_similarity <= -0.25 or total_similarity == -2.55)) or
                        (0 < gloss_similarity <= 0.06 and total_similarity < -0.63)
                    ):
                        lemmas.append({'literal_lemma': literal_lemma, 'mari_t_sense': mari_t_sense, 'iwn_sense': iwn_sense})
                    else:
                        print(f"Skipped - other : {literal_lemma} | MariTerm Sense: {mari_t_sense} | ItalWN Sense: {iwn_sense}")

    print(f"Final Selected Lemmas: {lemmas}")
    print(f"Total selected:{len(lemmas)}")
    return lemmas

def retrieve_wm(root):
    return {(word.find('.//LITERAL').get('LEMMA'), word.find('.//LITERAL').get('SENSE')): word for word in root.findall('.//WORD_MEANING')}

def find_word_meaning_in_root(root, lemma, sense):
    """
    Utility function to find a word meaning in a given XML root by lemma and sense.
    """
    for wm in root.findall('.//WORD_MEANING'):
        for literal in wm.findall('.//LITERAL'):
            if literal.get('LEMMA') == lemma and literal.get('SENSE') == sense:
                return wm
    return None

def get_new_id(existing_ids):
    numeric_ids = [int(id.split('#')[1]) for id in existing_ids if '#' in id and id.split('#')[1].isdigit()]
    return max(numeric_ids, default=0) + 1

def get_gloss_from_italwn(lemma, sense, root, pos=None):
    for word in root.findall('.//WORD_MEANING'):
        literal = word.find('.//LITERAL')
        word_pos = word.get('PART_OF_SPEECH')
        if literal is not None and literal.get('LEMMA') == lemma and literal.get('SENSE') == sense and (pos is None or word_pos == pos):
            gloss_element = word.find('.//GLOSS')
            if gloss_element is not None and gloss_element.text:
                return gloss_element.text.strip()
    return None

def extract_target_ids(root):
    return {(word.find('.//LITERAL').get('LEMMA'), word.find('.//LITERAL').get('SENSE')): word.get('ID') for word in root.findall('.//WORD_MEANING')}

def retrieve_relation_ids(iwn_root):
    return {
        rel.get('TYPE'): {'ID': rel.get('ID'), 'INV_ID': rel.get('INV_ID')}
        for rel in iwn_root.findall('.//RELATION') if rel.get('ID') and rel.get('INV_ID')
    }

def determine_inverse_relation(rel_type):
    inverse_map = {
        "has_hyperonym": "has_hyponym",
        "has_hyponym": "has_hyperonym",
        "near_synonym": "near_synonym",
        "has_xpos_hyperonym": "has_xpos_hyponym",
        "has_xpos_hyponym": "has_xpos_hyperonym",
        "xpos_near_synonym": "xpos_near_synonym"
    }
    return inverse_map.get(rel_type, rel_type)

def clean_target_wm_id(target_wm):
    """Remove any prefix (e.g., 'V#') from the ID of a TARGET_WM element."""
    clean_id = target_wm.get('ID').split('#')[-1]
    target_wm.set('ID', clean_id)

def remove_duplicate_relations(iwn_root):
    """
    Remove duplicate relations within each WORD_MEANING in the XML.
    """
    for word_meaning in iwn_root.findall('.//WORD_MEANING'):
        internal_links = word_meaning.find('.//INTERNAL_LINKS')
        if internal_links is not None:
            # Use a set to track unique relation signatures
            seen_relations = set()
            relations_to_remove = []
            
            for relation in internal_links.findall('.//RELATION'):
                # Create a unique identifier for each relation based on its type, target WM ID, and sense
                relation_signature = (
                    relation.get('TYPE'),
                    relation.find('.//TARGET_WM').get('ID'),
                    relation.find('.//TARGET_WM').get('SENSE')
                )
                
                # If this signature has already been seen, mark the relation for removal
                if relation_signature in seen_relations:
                    relations_to_remove.append(relation)
                else:
                    seen_relations.add(relation_signature)
            
            # Remove the duplicates
            for relation in relations_to_remove:
                internal_links.remove(relation)

def extract_eq_links_and_top_onto(root):
    eq_links, top_onto = {}, {}
    for word in root.findall('.//WORD_MEANING'):
        key = (word.find('.//LITERAL').get('LEMMA'), word.find('.//LITERAL').get('SENSE'))
        
        # Explicitly check if the elements exist
        eq_link_elem = word.find('.//EQ_LINKS')
        top_onto_elem = word.find('.//TOP_ONTO')
        
        eq_links[key] = eq_link_elem if eq_link_elem is not None else ET.Element('EQ_LINKS')
        top_onto[key] = top_onto_elem if top_onto_elem is not None else ET.Element('TOP_ONTO')

    return eq_links, top_onto

def merge_sections(existing_section, new_section):
    existing_relations = {ET.tostring(rel) for rel in existing_section.findall('.//RELATION')}
    for new_rel in new_section.findall('.//RELATION'):
        if ET.tostring(new_rel) not in existing_relations:
            # Clean the IDs in the TARGET_WM elements
            for target_wm in new_rel.findall('.//TARGET_WM'):
                clean_target_wm_id(target_wm)
            existing_section.append(new_rel)

def clean_existing_target_wm_ids(root):
    """Clean the IDs of all TARGET_WM elements in the provided root."""
    for target_wm in root.findall('.//TARGET_WM'):
        clean_target_wm_id(target_wm)

def clean_and_move_eq_links_at_end(iwn_root):
    """
    This function ensures that any 'eq_*' relations that ended up in INTERNAL_LINKS
    are moved to the EQ_LINKS section, if applicable.
    It also sorts the relations first by ID and then alphabetically by lemma.
    """
    for word_meaning in iwn_root.findall('.//WORD_MEANING'):
        internal_links = word_meaning.find('.//INTERNAL_LINKS')
        eq_links_section = word_meaning.find('.//EQ_LINKS')

        # Updated line to avoid DeprecationWarning
        if internal_links is not None and eq_links_section is not None:
            # Collect any eq_* relations
            eq_relations_to_move = [rel for rel in internal_links.findall('.//RELATION') if rel.get('TYPE', '').startswith('eq_')]

            # Move them to EQ_LINKS
            for rel in eq_relations_to_move:
                internal_links.remove(rel)
                eq_links_section.append(rel)

        # Updated line to avoid DeprecationWarning
        if internal_links is not None:
            relations = sorted(
                internal_links.findall('.//RELATION'),
                key=lambda r: (
                    int(r.get('ID')) if r.get('ID', '').isdigit() else float('inf'),
                    r.find('.//TARGET_WM').get('LEMMA', '').lower()
                )
            )

            # Clear existing relations and re-append sorted relations
            for rel in internal_links.findall('.//RELATION'):
                internal_links.remove(rel)
            for rel in relations:
                internal_links.append(rel)

        # Updated line to avoid DeprecationWarning
        if eq_links_section is not None:
            eq_relations = sorted(
                eq_links_section.findall('.//RELATION'),
                key=lambda r: (
                    int(r.get('ID')) if r.get('ID', '').isdigit() else float('inf'),
                    r.find('.//TARGET_WM').get('LEMMA', '').lower()
                )
            )

            # Clear existing relations and re-append sorted relations
            for rel in eq_links_section.findall('.//RELATION'):
                eq_links_section.remove(rel)
            for rel in eq_relations:
                eq_links_section.append(rel)

def sort_word_meanings_by_lemma_and_sense(root):
    word_meanings = sorted(root.findall('.//WORD_MEANING'), key=lambda wm: (wm.find('.//LITERAL').get('LEMMA').lower(), wm.find('.//LITERAL').get('SENSE')))
    for word in word_meanings:
        root.remove(word)
    for word in word_meanings:
        root.append(word)

def remove_redundant_word_meanings(iwn_root):
    for replacement in replaced_glosses:
        for word_meaning in iwn_root.findall('.//WORD_MEANING'):
            literal = word_meaning.find('.//LITERAL')
            gloss_element = word_meaning.find('.//GLOSS')
            if literal is not None and gloss_element is not None:
                if literal.get('LEMMA') == replacement['lemma'] and gloss_element.text.strip() == replacement['original_gloss']:
                    iwn_root.remove(word_meaning)
                    print(f"Removed redundant word meaning for {replacement['lemma']} with replaced gloss: '{replacement['original_gloss']}'")

def replace_gloss_with_original(iwn_root, original_iwn_root, updated_entries):
    replaced_glosses_set = set()

    for iwn_wm in iwn_root.findall('.//WORD_MEANING'):
        lemma = iwn_wm.find('.//LITERAL').get('LEMMA')
        sense = iwn_wm.find('.//LITERAL').get('SENSE')
        pos = iwn_wm.get('PART_OF_SPEECH')

        if (lemma, sense) in updated_entries:
            continue  # Skip this entry if it has already been updated

        original_gloss = get_gloss_from_italwn(lemma, sense, original_iwn_root, pos)

        if original_gloss:
            iwn_gloss_element = iwn_wm.find('.//GLOSS')
            current_gloss = iwn_gloss_element.text.strip() if iwn_gloss_element is not None and iwn_gloss_element.text else None
            if current_gloss != original_gloss:
                if iwn_gloss_element is not None:
                    iwn_gloss_element.text = original_gloss
                else:
                    iwn_gloss_element = ET.SubElement(iwn_wm, 'GLOSS')
                    iwn_gloss_element.text = original_gloss

                # Print the replacement message only if it hasn't been printed for this lemma-sense-pos combination
                if (lemma, sense, pos) not in replaced_glosses_set:
                    print(f"Replaced WORD_MEANING gloss for '{lemma}' sense '{sense}' with original IWN gloss.")
                    replaced_glosses_set.add((lemma, sense, pos))

            # Replace glosses in TARGET_WM elements
            for target_wm in iwn_root.findall(f'.//TARGET_WM[@LEMMA="{lemma}"][@SENSE="{sense}"][@PART_OF_SPEECH="{pos}"]'):
                target_gloss = target_wm.get('GLOSS')
                if target_gloss != original_gloss:
                    target_wm.set('GLOSS', original_gloss)

                    # Print the replacement message only if it hasn't been printed for this lemma-sense-pos combination
                    if (lemma, sense, pos) not in replaced_glosses_set:
                        print(f"Replaced TARGET_WM gloss for '{lemma}' sense '{sense}' with original IWN gloss.")
                        replaced_glosses_set.add((lemma, sense, pos))

def create_or_merge_word_meaning(lemma, sense, existing_ids, mari_eq_links, mari_top_onto, iwn_root, back_references=[], relation_ids=None, gloss="", add_lfeatures_due_to_hyponym=False, add_lfeatures_due_to_non_compliance=False, original_iwn_root=None):
    updated_entries.add((lemma, sense))
    word_meaning = find_word_meaning_in_root(iwn_root, lemma, sense) 
    if word_meaning is None:
        word_meaning = find_word_meaning_in_root(original_iwn_root, lemma, sense)
    
    if word_meaning is not None:
        word_meaning_id = word_meaning.get('ID')
        gloss_element = word_meaning.find('.//GLOSS')
        original_gloss = gloss_element.text.strip() if gloss_element is not None and gloss_element.text else ''
        
        if original_gloss != gloss:
            if gloss_element is None:
                gloss_element = ET.SubElement(word_meaning, 'GLOSS')
            gloss_element.text = gloss
        return word_meaning, word_meaning_id
    
    pos_prefix = back_references[0]['part_of_speech'] if back_references else "N"
    new_id = get_new_id(existing_ids)
    word_meaning_id = f"{pos_prefix}#{new_id}"
    existing_ids.add(word_meaning_id)
    
    word_meaning = ET.Element('WORD_MEANING', ID=word_meaning_id, PART_OF_SPEECH=pos_prefix)
    gloss_element = ET.SubElement(word_meaning, 'GLOSS')
    gloss_element.text = gloss

    variants = ET.SubElement(word_meaning, 'VARIANTS')
    literal_node = ET.SubElement(variants, 'LITERAL', LEMMA=lemma, SENSE=str(sense))

    if add_lfeatures_due_to_hyponym or add_lfeatures_due_to_non_compliance:
        ET.SubElement(literal_node, 'LFEATURES', SUBLANGUAGE="mar")

    internal_links = ET.SubElement(word_meaning, 'INTERNAL_LINKS')
    eq_links_section = ET.SubElement(word_meaning, 'EQ_LINKS')
    top_onto_section = ET.SubElement(word_meaning, 'TOP_ONTO')

    iwn_root.append(word_meaning)
    new_word_meanings.append(lemma)

    key = (lemma, sense)
    if key in mari_eq_links:
        merge_sections(eq_links_section, mari_eq_links[key])
    if key in mari_top_onto:
        merge_sections(top_onto_section, mari_top_onto[key])

    for ref in back_references:
        rel_type, target_lemma = ref['inverse_relation'], ref['lemma']
        section = internal_links if not rel_type.startswith('eq_') else eq_links_section
        existing_relations = {
            (rel.get('TYPE'), rel.find('.//TARGET_WM').get('LEMMA')): rel
            for rel in section.findall('.//RELATION')
        }
        
        if (rel_type, target_lemma) not in existing_relations:
            rel_id, inv_id = relation_ids.get(rel_type, {}).get('ID', 'UNKNOWN'), relation_ids.get(rel_type, {}).get('INV_ID', 'UNKNOWN')
            new_rel = ET.SubElement(section, 'RELATION', TYPE=rel_type, ID=rel_id, INV_ID=inv_id)
            
            target_wm = ET.SubElement(new_rel, 'TARGET_WM', ID=ref['id'], PART_OF_SPEECH=ref['part_of_speech'], LEMMA=ref['lemma'], SENSE=ref['sense'])
            clean_target_wm_id(target_wm)  # Ensure the ID is cleaned
            
            if ref.get('gloss'):
                target_wm.set('GLOSS', ref['gloss'])
    
    return word_meaning, word_meaning_id

def update_iwn_entries(selected_lemmas, mari_root, iwn_root, original_mari_root, original_iwn_root):
    mari_meanings = retrieve_wm(mari_root)
    original_target_ids = extract_target_ids(original_iwn_root)
    mari_eq_links, mari_top_onto = extract_eq_links_and_top_onto(original_mari_root)
    existing_ids = {word.get('ID') for word in iwn_root.findall('.//WORD_MEANING')}
    relation_ids = retrieve_relation_ids(iwn_root)

    relations_added = 0
    word_meanings_created = 0
    lemmas_processed = 0

    allowed_relation_types = {
        "has_hyperonym", 
        "has_hyponym", 
        "near_synonym", 
        "has_xpos_hyperonym", 
        "has_xpos_hyponym", 
        "xpos_near_synonym"
    }

    def retrieve_or_generate_gloss(target_lemma, target_sense, main_gloss=None):
        italwn_gloss = get_gloss_from_italwn(target_lemma, target_sense, iwn_root)
        mariterm_gloss = get_gloss_from_relation_in_mariterm(target_lemma, target_sense, mari_meanings)
        italwn_gloss_original = None

        if not italwn_gloss and not mariterm_gloss:
            italwn_gloss_original = get_gloss_from_italwn(target_lemma, target_sense, original_iwn_root)
            if italwn_gloss_original:
                print(f"Special case: Found gloss for '{target_lemma}' sense '{target_sense}' in original IWN.")
                return italwn_gloss_original

        if mariterm_gloss and italwn_gloss and mariterm_gloss != italwn_gloss:
            replaced_glosses.append({"lemma": target_lemma, "sense": target_sense, "original_gloss": mariterm_gloss})
            print(f"Replacing gloss for '{target_lemma}' (sense {target_sense}). Original: '{mariterm_gloss}', New: '{italwn_gloss}'")

        return italwn_gloss if italwn_gloss else mariterm_gloss

    def get_gloss_from_relation_in_mariterm(target_lemma, target_sense, mari_meanings):
        for mari_word in mari_meanings.values():
            for rel in mari_word.findall('.//INTERNAL_LINKS//RELATION'):
                target_wm = rel.find('.//TARGET_WM')
                if target_wm is not None and target_wm.get('LEMMA') == target_lemma and target_wm.get('SENSE') == target_sense:
                    return target_wm.get('GLOSS', '').strip()
        return ""

    for entry in selected_lemmas:
        lemma, mari_sense, iwn_sense = entry['literal_lemma'], entry['mari_t_sense'], entry['iwn_sense']
        lemmas_processed += 1
        
        mari_word = mari_meanings.get((lemma, mari_sense))
        if mari_word is None:
            print(f"Skipped: MariTerm sense {mari_sense} for {lemma} not found in MariTerm filtered.")
            continue  # Skip to the next iteration if mari_word is None

        mari_gloss_element = mari_word.find('.//GLOSS')
        mari_gloss = mari_gloss_element.text.strip() if mari_gloss_element is not None and mari_gloss_element.text else ''
    
        if any(r['lemma'] == lemma and r['sense'] == mari_sense and r['original_gloss'] == mari_gloss for r in replaced_glosses):
            print(f"Skipping redundant creation for lemma '{lemma}' with sense '{mari_sense}' and gloss '{mari_gloss}'")
            continue

        word_meaning, _ = create_or_merge_word_meaning(
            lemma, iwn_sense, existing_ids, mari_eq_links, mari_top_onto, iwn_root, [], relation_ids,
            gloss=retrieve_or_generate_gloss(lemma, iwn_sense, mari_gloss),
            original_iwn_root=original_iwn_root
        )
        word_meanings_created += 1 if word_meaning is not None else 0

        for rel in mari_word.findall('.//INTERNAL_LINKS//RELATION'):
            rel_type = rel.get('TYPE')
            if rel_type not in allowed_relation_types:
                continue

            target_lemma = rel.find('.//TARGET_WM').get('LEMMA', '')
            target_sense = rel.find('.//TARGET_WM').get('SENSE')
            target_gloss = retrieve_or_generate_gloss(target_lemma, target_sense, mari_gloss)

            target_id = original_target_ids.get((target_lemma, target_sense))
            if not target_id:
                back_references = [{
                    "id": word_meaning.get('ID'),
                    "inv_id": relation_ids[rel_type]['INV_ID'],
                    "part_of_speech": word_meaning.get('PART_OF_SPEECH'),
                    "lemma": lemma,
                    "sense": iwn_sense,
                    "gloss": mari_gloss,
                    "inverse_relation": determine_inverse_relation(rel_type)
                }]
                new_wm, target_id = create_or_merge_word_meaning(
                    target_lemma, target_sense, existing_ids, mari_eq_links, mari_top_onto, iwn_root, back_references, relation_ids,
                    original_iwn_root=original_iwn_root
                )
                word_meanings_created += 1 if new_wm is not None else 0

            if rel_type in relation_ids:
                new_rel = ET.SubElement(word_meaning.find('.//INTERNAL_LINKS'), 'RELATION', TYPE=rel_type, ID=relation_ids[rel_type]['ID'], INV_ID=relation_ids[rel_type]['INV_ID'])
                new_target_wm = ET.SubElement(new_rel, 'TARGET_WM', ID=target_id.replace(f"{word_meaning.get('PART_OF_SPEECH')}#", ""), PART_OF_SPEECH=rel.find('.//TARGET_WM').get('PART_OF_SPEECH'), LEMMA=target_lemma, SENSE=target_sense)
                if target_gloss:
                    new_target_wm.set('GLOSS', target_gloss)
                relations_added += 1

    clean_and_move_eq_links_at_end(iwn_root)
    remove_redundant_word_meanings(iwn_root)
    sort_word_meanings_by_lemma_and_sense(iwn_root)
    replace_gloss_with_original(iwn_root, original_iwn_root, updated_entries)

    #print(f"Total lemmas processed: {lemmas_processed}")
    # Print the total number of word meanings in the final IWN file
    total_word_meanings = len(iwn_root.findall('.//WORD_MEANING'))
    print(f"Total relations added: {relations_added}")
    print(f"New Word Meanings Created: {new_word_meanings}")
    print(f"Total brand new WM: {len(new_word_meanings)}")
    print(f"Total word meanings in the file: {total_word_meanings}")

# Process CSV and XML files
selected_lemmas = read_lemmas_from_csv(breakdown_csv)
tree_mari = ET.parse(filt_mart)
mari_root = tree_mari.getroot()
tree_iwn = ET.parse(filt_iwn)
iwn_root = tree_iwn.getroot()
tree_original_mari = ET.parse(MariT)
original_mari_root = tree_original_mari.getroot()
tree_original_iwn = ET.parse(ItalWN)
original_iwn_root = tree_original_iwn.getroot()


updated_entries = set()  # Track updated (lemma, sense) pairs

# Update IWN entries
update_iwn_entries(selected_lemmas, mari_root, iwn_root, original_mari_root, original_iwn_root)

replace_gloss_with_original(iwn_root, original_iwn_root, updated_entries)

# Clean up TARGET_WM IDs to ensure they only contain numbers
clean_existing_target_wm_ids(iwn_root)

# Remove duplicate relations
remove_duplicate_relations(iwn_root)

# Save the updated IWN file
ET.ElementTree(iwn_root).write(updates, encoding='utf-8', xml_declaration=True)
print("Update complete.")

# %%
def merge_and_format_iwn_files(ItalWN, updates, New_IWN):
    # Parse the original unfiltered IWN and the final output files
    tree_original = ET.parse(ItalWN)
    root_original = tree_original.getroot()

    tree_output = ET.parse(updates)
    root_output = tree_output.getroot()

    # Create a dictionary to store word meanings from the final output file by (lemma, sense)
    output_wm_dict = {}
    for word_meaning in root_output.findall('.//WORD_MEANING'):
        lemma = word_meaning.find('.//LITERAL').get('LEMMA')
        sense = word_meaning.find('.//LITERAL').get('SENSE')
        output_wm_dict[(lemma, sense)] = word_meaning

    # Merge the original IWN with the final output, replacing old entries with new ones
    merged_wm_list = []
    for word_meaning in root_original.findall('.//WORD_MEANING'):
        lemma = word_meaning.find('.//LITERAL').get('LEMMA')
        sense = word_meaning.find('.//LITERAL').get('SENSE')

        # If there's an updated version in the output file, use that one
        if (lemma, sense) in output_wm_dict:
            merged_wm_list.append(output_wm_dict.pop((lemma, sense)))
        else:
            merged_wm_list.append(word_meaning)

    # Add any remaining new word meanings from the final output file
    merged_wm_list.extend(output_wm_dict.values())

    # Sort the word meanings alphabetically by the first LITERAL LEMMA
    merged_wm_list.sort(key=lambda wm: (wm.find('.//LITERAL').get('LEMMA').lower(), wm.find('.//LITERAL').get('SENSE')))

    # Create a new XML tree for the merged content
    new_root = ET.Element(root_original.tag)

    for word_meaning in merged_wm_list:
        new_root.append(word_meaning)

    # Write the merged and formatted XML to a new file
    tree_merged = ET.ElementTree(new_root)
    tree_merged.write(New_IWN, encoding='utf-8', xml_declaration=True)

    # Format the XML with indentation
    format_xml_with_indentation(New_IWN)

    print(f"Merged IWN file created and saved as '{New_IWN}'")

def format_xml_with_indentation(file_path):
    """Format the XML file with proper indentation and remove unnecessary blank lines."""
    import xml.dom.minidom
    import re

    # Read the file and parse it into an XML document
    with open(file_path, 'r', encoding='utf-8') as file:
        xml_str = file.read()

    # Parse the XML string
    dom = xml.dom.minidom.parseString(xml_str)

    # Pretty print with indentation
    pretty_xml_as_string = dom.toprettyxml(indent="  ")

    # Remove extra blank lines
    pretty_xml_as_string = re.sub(r'\n\s*\n', '\n', pretty_xml_as_string)

    # Write the cleaned and pretty-printed XML back to the file
    with open(file_path, 'w', encoding='utf-8') as file:
        file.write(pretty_xml_as_string)

merge_and_format_iwn_files(ItalWN, updates, New_IWN)

# %% [markdown]
# # [Post-hoc]
# a. Estrazione del numero di WORD MEANING @ID da inserire per eventuale creazione manuale di nuove voci in IWN
#
# b. Tracciamento delle nuove voci e delle relazioni semantiche aggiunte
#
# b. Aggiunta di una PLUG-IN_LINKS a tutte le voci, con le dovute informazioni sulla voce di MariTerm associata (ove applicabile)

# %%
def get_last_word_meaning_id(file):
    """
    This function reads an XML file and returns the highest numeric ID of a Word Meaning (WM).
    """
    tree = ET.parse(New_IWN)
    root = tree.getroot()
    
    # Initialize the highest ID variable
    max_id = 0
    
    # Iterate through all WORD_MEANING elements
    for word_meaning in root.findall('.//WORD_MEANING'):
        wm_id = word_meaning.get('ID')
        if wm_id and '#' in wm_id:
            # Extract the numeric part of the ID
            numeric_id = int(wm_id.split('#')[-1])
            # Update max_id if the current one is higher
            if numeric_id > max_id:
                max_id = numeric_id
    
    return max_id + 1

# Example usage:
last_id = get_last_word_meaning_id(New_IWN)
print(f"Next ID to add: {last_id}")

# %%
def extract_internal_links(wm):
    """Extract all relations in INTERNAL_LINKS."""
    return {(rel.get('TYPE'), rel.find('.//TARGET_WM').get('LEMMA'), rel.find('.//TARGET_WM').get('SENSE')): rel
            for rel in wm.findall('.//INTERNAL_LINKS//RELATION')}

def identify_updates_in_iwn(ItalWN, plug_att):
    original_tree = ET.parse(ItalWN)
    original_root = original_tree.getroot()

    finalized_tree = ET.parse(plug_att)
    finalized_root = finalized_tree.getroot()

    updated_synsets = []
    new_synsets = []
    new_word_meanings_info = []
    newly_added_relations_info = []

    original_word_meanings = {
        (wm.find('.//LITERAL').get('LEMMA'), wm.find('.//LITERAL').get('SENSE')): wm
        for wm in original_root.findall('.//WORD_MEANING')
    }

    relevant_relation_types = {'near_synonym', 'has_hyperonym', 'has_hyponym'}

    for finalized_wm in finalized_root.findall('.//WORD_MEANING'):
        lemma = finalized_wm.find('.//LITERAL').get('LEMMA')
        sense = finalized_wm.find('.//LITERAL').get('SENSE')

        if (lemma, sense) not in original_word_meanings:
            # New synset
            new_synsets.append(finalized_wm)
            new_word_meanings_info.append((lemma, sense))
        else:
            original_wm = original_word_meanings[(lemma, sense)]

            # Extract internal links (relations) from both original and finalized word meanings
            original_internal_links = extract_internal_links(original_wm)
            finalized_internal_links = extract_internal_links(finalized_wm)

            # Filter the new relations to include only the relevant types
            new_relations = {key: finalized_internal_links[key] for key in finalized_internal_links
                             if key not in original_internal_links and key[0] in relevant_relation_types}

            if new_relations:
                updated_synsets.append((finalized_wm, new_relations))
                newly_added_relations_info.extend([key for key in new_relations.keys() if key[0] in relevant_relation_types])

    return updated_synsets, new_synsets, new_word_meanings_info, newly_added_relations_info
# Replace 'ItalWN' and 'plug_att' with your actual file paths
updated_entries, new_entries, new_word_meanings_info, newly_added_relations_info = identify_updates_in_iwn(ItalWN, plug_att)

# Display new entries
print("New Entries:")
for lemma, sense in new_word_meanings_info:
    print(f"Lemma: {lemma}, Sense: {sense}")

# Display newly added relations
print("\nNewly Added Relations:")
for rel_type, target_lemma, target_sense in newly_added_relations_info:
    print(f"Relation Type: {rel_type}, Target Lemma: {target_lemma}, Target Sense: {target_sense}")
# Out:
# New Entries:
# Lemma: abbadernare, Sense: 1
# Lemma: abbordaggio intenzionale, Sense: 1
# Lemma: acazia, Sense: 1
# Lemma: acronimo, Sense: 2
# Lemma: addetto navale, Sense: 1
# Lemma: agenzia marittima, Sense: 1
# Lemma: ago da velaio, Sense: 1
# Lemma: ala di colomba, Sense: 1
# Lemma: alaggio, Sense: 2
# Lemma: albero di carico, Sense: 1
# Lemma: albero di controvelaccino, Sense: 1
# Lemma: albero di parrocchetto, Sense: 1
# Lemma: albero di poppa, Sense: 1
# Lemma: albero di velaccino, Sense: 1
# Lemma: alfabeto internazionale, Sense: 1
# Lemma: alimentari, Sense: 1
# Lemma: altezza dell'acqua, Sense: 1
# Lemma: altezza di una stella, Sense: 1
# Lemma: altezza metacentrica, Sense: 1
# Lemma: ancora a fungo, Sense: 1
# Lemma: ancora ad aratro, Sense: 1
# Lemma: ancora Ammiragliato, Sense: 1
# Lemma: ancora Danforth, Sense: 1
# Lemma: ancora di rispetto, Sense: 1
# Lemma: ancora galleggiante, Sense: 1
# Lemma: ancora Hall, Sense: 1
# Lemma: ancorotto, Sense: 1
# Lemma: andare alla deriva, Sense: 1
# Lemma: andatura al giardinetto, Sense: 1
# Lemma: andatura al mascone, Sense: 1
# Lemma: andatura alla cappa, Sense: 1
# Lemma: andatura di bolina larga, Sense: 1
# Lemma: andatura mura a dritta, Sense: 1
# Lemma: andatura mura a sinistra, Sense: 1
# Lemma: angolo di barra, Sense: 1
# Lemma: angolo di deriva, Sense: 1
# Lemma: angolo di sbandamento, Sense: 1
# Lemma: angolo orario, Sense: 1
# Lemma: antincendio, Sense: 1
# Lemma: armamento di fortuna, Sense: 1
# Lemma: arridatoio, Sense: 1
# Lemma: articolo soggetto a limitazione, Sense: 1
# Lemma: assicurare la bandiera, Sense: 1
# Lemma: assicurazione della merce, Sense: 1
# Lemma: astronomia nautica, Sense: 1
# Lemma: attestazione dello spedizioniere di presa in consegna, Sense: 1
# Lemma: avaria generale, Sense: 1
# Lemma: avaria particolare, Sense: 1
# Lemma: avvisatore acustico, Sense: 1
# Lemma: avvisatore marittimo, Sense: 1
# Lemma: avvolgifiocco, Sense: 1
# Lemma: avvolgiranda, Sense: 1
# Lemma: bacino di allestimento, Sense: 1
# Lemma: bacino galleggiante, Sense: 1
# Lemma: baglio maestro, Sense: 2
# Lemma: baglio massimo, Sense: 1
# Lemma: barbotta, Sense: 1
# Lemma: barca a motore, Sense: 1
# Lemma: barca a remi, Sense: 1
# Lemma: barca di salvataggio, Sense: 1
# Lemma: barco, Sense: 1
# Lemma: barra a dritta, Sense: 1
# Lemma: barra a sinistra, Sense: 1
# Lemma: barra sopravvento, Sense: 1
# Lemma: barra sottovento, Sense: 1
# Lemma: basso fondale, Sense: 1
# Lemma: bava di vento, Sense: 1
# Lemma: bitta, Sense: 2
# Lemma: bolletta di consegna, Sense: 1
# Lemma: borosa, Sense: 1
# Lemma: brancarella, Sense: 1
# Lemma: brezza di mare, Sense: 1
# Lemma: brezza di terra, Sense: 1
# Lemma: briccola, Sense: 1
# Lemma: cabina di poppa, Sense: 1
# Lemma: cabotare, Sense: 1
# Lemma: cacciatorpediniere, Sense: 1
# Lemma: cala vele, Sense: 1
# Lemma: calma piatta, Sense: 1
# Lemma: campana del tangone, Sense: 1
# Lemma: campione senza valore commerciale, Sense: 1
# Lemma: cantilever, Sense: 1
# Lemma: cappio del pescatore, Sense: 1
# Lemma: caracca, Sense: 1
# Lemma: caracora, Sense: 1
# Lemma: caricabasso, Sense: 1
# Lemma: carico completo, Sense: 1
# Lemma: carico di merci varie, Sense: 1
# Lemma: carico parziale, Sense: 1
# Lemma: carpenteria, Sense: 2
# Lemma: carpenteria metallica, Sense: 1
# Lemma: carro ferroviario, Sense: 1
# Lemma: carta nautica, Sense: 1
# Lemma: cassa della deriva, Sense: 1
# Lemma: cassa di zavorra, Sense: 1
# Lemma: cassa mobile, Sense: 1
# Lemma: cassero, Sense: 2
# Lemma: cavo di alaggio, Sense: 1
# Lemma: ceppo dell'ancora, Sense: 1
# Lemma: certificato di origine, Sense: 1
# Lemma: certificato di trasporto emesso dallo spedizioniere, Sense: 1
# Lemma: chalutier, Sense: 1
# Lemma: cirro-cumolo, Sense: 1
# Lemma: classe, Sense: 9
# Lemma: classe a formula, Sense: 1
# Lemma: classe a restrizione, Sense: 1
# Lemma: classe monotipo, Sense: 1
# Lemma: clausola della nazione più favorita, Sense: 1
# Lemma: clipper, Sense: 1
# Lemma: Codice della Navigazione, Sense: 1
# Lemma: Codice Doganale, Sense: 1
# Lemma: Codice Internazionale dei Segnali, Sense: 1
# Lemma: Codice Marittimo, Sense: 1
# Lemma: codice morse, Sense: 1
# Lemma: codice porto secondo IMO, Sense: 1
# Lemma: coefficiente di finezza, Sense: 1
# Lemma: collo, Sense: 6
# Lemma: commissione sul nolo, Sense: 1
# Lemma: compagnia di navigazione, Sense: 1
# Lemma: condizione della "Conference", Sense: 1
# Lemma: consegna totale, Sense: 1
# Lemma: controfiocco, Sense: 1
# Lemma: corpo morto, Sense: 1
# Lemma: corrente calda, Sense: 1
# Lemma: corrente continua, Sense: 1
# Lemma: corrente di marea, Sense: 1
# Lemma: corrente di pendio, Sense: 1
# Lemma: corrente fredda, Sense: 1
# Lemma: corrente periodica, Sense: 1
# Lemma: corrente profonda, Sense: 1
# Lemma: corrente superficiale, Sense: 1
# Lemma: cumulonembo, Sense: 1
# Lemma: deck cargo, Sense: 1
# Lemma: declinazione magnetica, Sense: 1
# Lemma: deriva, Sense: 4
# Lemma: dichiarazione d'armatore, Sense: 1
# Lemma: diritti d'autore, Sense: 1
# Lemma: diritti doganali, Sense: 1
# Lemma: diritti portuali, Sense: 1
# Lemma: diritto di prelazione, Sense: 1
# Lemma: documenti d'esportazione, Sense: 1
# Lemma: documenti d'imbarco, Sense: 1
# Lemma: doppino, Sense: 1
# Lemma: dragamine, Sense: 1
# Lemma: drakar, Sense: 1
# Lemma: drifter, Sense: 1
# Lemma: drizza del fiocco, Sense: 1
# Lemma: dumler, Sense: 1
# Lemma: dundee, Sense: 1
# Lemma: dògre, Sense: 1
# Lemma: ecoscandaglio, Sense: 1
# Lemma: fare acqua, Sense: 1
# Lemma: fare provvista d'acqua, Sense: 1
# Lemma: ferramenta, Sense: 1
# Lemma: fondo buon tenitore, Sense: 1
# Lemma: fondo di alghe, Sense: 1
# Lemma: fondo fangoso, Sense: 1
# Lemma: fondo pietroso, Sense: 1
# Lemma: fondo roccioso, Sense: 1
# Lemma: fondo sabbioso, Sense: 1
# Lemma: frenello, Sense: 1
# Lemma: fuoritutto, Sense: 1
# Lemma: gassa d'amante, Sense: 1
# Lemma: gassa d'amante semplice, Sense: 1
# Lemma: gassa spagnola, Sense: 1
# Lemma: gavone, Sense: 2
# Lemma: gonioanemometro, Sense: 1
# Lemma: grippia, Sense: 1
# Lemma: grippiale, Sense: 1
# Lemma: grisella, Sense: 1
# Lemma: groppo, Sense: 2
# Lemma: igrografo, Sense: 1
# Lemma: imbando, Sense: 1
# Lemma: impalmatura, Sense: 1
# Lemma: impianto antincendio, Sense: 1
# Lemma: impianto di riscaldamento, Sense: 1
# Lemma: impianto elettrico, Sense: 1
# Lemma: impianto radio, Sense: 1
# Lemma: impoppata, Sense: 1
# Lemma: incappellaggio, Sense: 2
# Lemma: informazioni sui traghetti, Sense: 1
# Lemma: lezzino, Sense: 1
# Lemma: maestrale, Sense: 2
# Lemma: mandare via, Sense: 1
# Lemma: manica a vento, Sense: 1
# Lemma: manifestazione sportiva, Sense: 1
# Lemma: manifesto di carico, Sense: 1
# Lemma: manifesto doganale, Sense: 1
# Lemma: manovra corrente, Sense: 1
# Lemma: manovra dormiente, Sense: 1
# Lemma: mantenere la rotta, Sense: 1
# Lemma: mantiglio, Sense: 1
# Lemma: maona, Sense: 1
# Lemma: mare a montoni, Sense: 1
# Lemma: mare calmo, Sense: 1
# Lemma: mare corto, Sense: 1
# Lemma: mare di latte, Sense: 1
# Lemma: mare grosso, Sense: 1
# Lemma: mare incrociato, Sense: 1
# Lemma: mare lungo, Sense: 1
# Lemma: mare mosso, Sense: 1
# Lemma: mare poco mosso, Sense: 1
# Lemma: mare sporco, Sense: 1
# Lemma: marò, Sense: 2
# Lemma: materiale da costruzione, Sense: 1
# Lemma: materiale lapideo, Sense: 1
# Lemma: meolo, Sense: 1
# Lemma: meteorologia marittima, Sense: 1
# Lemma: meteorologia scientifica, Sense: 1
# Lemma: meteorologia sinottica, Sense: 1
# Lemma: meteorologia strumentale, Sense: 1
# Lemma: mezzocollo, Sense: 1
# Lemma: miglio marino, Sense: 1
# Lemma: miglio terrestre, Sense: 1
# Lemma: minuto primo, Sense: 1
# Lemma: minuto secondo, Sense: 1
# Lemma: motore a due tempi, Sense: 1
# Lemma: motore a quattro tempi, Sense: 1
# Lemma: motore ausiliario, Sense: 1
# Lemma: motore di avviamento, Sense: 1
# Lemma: motore entrobordo, Sense: 1
# Lemma: motore fuoribordo, Sense: 1
# Lemma: mura, Sense: 1
# Lemma: natante, Sense: 2
# Lemma: natante da diporto, Sense: 1
# Lemma: nautica da diporto, Sense: 1
# Lemma: nave feeder, Sense: 1
# Lemma: nave full container, Sense: 1
# Lemma: nave madre, Sense: 1
# Lemma: navicello, Sense: 1
# Lemma: navicert, Sense: 1
# Lemma: navigare al traverso, Sense: 1
# Lemma: navigare alla cappa, Sense: 1
# Lemma: navigatore, Sense: 3
# Lemma: navigazione a motore, Sense: 1
# Lemma: navigazione a vela, Sense: 1
# Lemma: navigazione di linea, Sense: 1
# Lemma: navigazione fluviale, Sense: 1
# Lemma: navigazione lacustre, Sense: 1
# Lemma: navigazione libera, Sense: 1
# Lemma: navigazione remica, Sense: 1
# Lemma: navigazione sottomarina, Sense: 1
# Lemma: nebbia di avvezione, Sense: 1
# Lemma: nebbia di irradiazione, Sense: 1
# Lemma: nebbia frontale, Sense: 1
# Lemma: nodo bandiera, Sense: 1
# Lemma: nodo d'anguilla, Sense: 1
# Lemma: nodo del barcaiolo, Sense: 1
# Lemma: nodo del cappuccino, Sense: 1
# Lemma: nodo del francescano, Sense: 1
# Lemma: nodo dell'impiccato, Sense: 1
# Lemma: nodo di ancorotto ganciato, Sense: 1
# Lemma: nodo di bolina, Sense: 1
# Lemma: nodo di bozza, Sense: 1
# Lemma: nodo inglese, Sense: 1
# Lemma: nodo margherita, Sense: 1
# Lemma: nodo parlato semplice, Sense: 1
# Lemma: nodo piano, Sense: 1
# Lemma: nodo portoghese, Sense: 1
# Lemma: nodo Savoia, Sense: 1
# Lemma: nodo scorsoio semplice, Sense: 1
# Lemma: nodo semplice, Sense: 1
# Lemma: nodo vaccaio, Sense: 1
# Lemma: nodo volante, Sense: 1
# Lemma: onda lunga, Sense: 1
# Lemma: ordine di consegna, Sense: 1
# Lemma: pastecca, Sense: 1
# Lemma: petroliera, Sense: 2
# Lemma: piranometro, Sense: 1
# Lemma: polizza di carico, Sense: 1
# Lemma: poppa a canoa, Sense: 1
# Lemma: poppa a specchio, Sense: 1
# Lemma: poppa stretta, Sense: 1
# Lemma: portata geografica, Sense: 1
# Lemma: portata luminosa, Sense: 1
# Lemma: porti d'Europa, Sense: 1
# Lemma: porto di armamento, Sense: 1
# Lemma: porto di scalo, Sense: 1
# Lemma: porto di trasbordo, Sense: 1
# Lemma: porto feeder, Sense: 1
# Lemma: Porto in Toscana, Sense: 1
# Lemma: prodiero, Sense: 1
# Lemma: prodotto chimico, Sense: 1
# Lemma: prodotto forestale, Sense: 1
# Lemma: prodotto siderurgico, Sense: 1
# Lemma: prua a canoa, Sense: 1
# Lemma: prua a ruota, Sense: 1
# Lemma: prua bussola, Sense: 1
# Lemma: prua diritta, Sense: 1
# Lemma: prua magnetica, Sense: 1
# Lemma: prua sottile, Sense: 1
# Lemma: prua vera, Sense: 1
# Lemma: pugno di scimmia, Sense: 1
# Lemma: ralinga, Sense: 1
# Lemma: rata di nolo, Sense: 1
# Lemma: regata velica, Sense: 1
# Lemma: risalire il fiume, Sense: 1
# Lemma: rotta di collisione, Sense: 1
# Lemma: rotta ortodromica, Sense: 1
# Lemma: rotta stimata, Sense: 1
# Lemma: rotta vera, Sense: 1
# Lemma: rough sea, Sense: 1
# Lemma: scala di Beaufort, Sense: 1
# Lemma: scala Douglas, Sense: 1
# Lemma: scalo d'alaggio, Sense: 1
# Lemma: scoglio sommerso, Sense: 1
# Lemma: scotta del fiocco, Sense: 1
# Lemma: scotta di randa, Sense: 1
# Lemma: segnale marittimo, Sense: 1
# Lemma: sigizia, Sense: 1
# Lemma: sopranolo, Sense: 1
# Lemma: SOS, Sense: 1
# Lemma: spedizioniere doganale, Sense: 1
# Lemma: spese d'imbarco, Sense: 1
# Lemma: spese di carico, Sense: 1
# Lemma: spese di magazzinaggio, Sense: 1
# Lemma: spese di sosta, Sense: 1
# Lemma: stato del mare, Sense: 1
# Lemma: stazione marittima, Sense: 1
# Lemma: strallo, Sense: 1
# Lemma: straorzata, Sense: 1
# Lemma: strato di pittura, Sense: 1
# Lemma: struttura metallica, Sense: 1
# Lemma: superficie velica, Sense: 1
# Lemma: tambuccio, Sense: 1
# Lemma: tariffa di trasporto, Sense: 1
# Lemma: tariffa doganale, Sense: 1
# Lemma: tariffa forfettaria, Sense: 1
# Lemma: tavola da surf, Sense: 1
# Lemma: tesabugna, Sense: 1
# Lemma: timone compensato, Sense: 1
# Lemma: timone sospeso, Sense: 1
# Lemma: tonneggiare, Sense: 1
# Lemma: tromba marina, Sense: 1
# Lemma: trozza, Sense: 1
# Lemma: turbolenza atmosferica, Sense: 1
# Lemma: Twenty Equivalent Unit, Sense: 1
# Lemma: ufficio della dogana, Sense: 1
# Lemma: unità di carico, Sense: 1
# Lemma: uomo in mare, Sense: 1
# Lemma: velico, Sense: 2
# Lemma: velico, Sense: 3
# Lemma: venti locali del Mediterraneo, Sense: 1
# Lemma: vento, Sense: 2
# Lemma: vento a raffiche, Sense: 1
# Lemma: vento al traverso, Sense: 1
# Lemma: vento apparente, Sense: 1
# Lemma: vento contrario, Sense: 1
# Lemma: vento costante, Sense: 1
# Lemma: vento di prua, Sense: 1
# Lemma: vento dominante, Sense: 1
# Lemma: vento favorevole, Sense: 1
# Lemma: vento in poppa, Sense: 1
# Lemma: vento locale, Sense: 1
# Lemma: vento periodico, Sense: 1
# Lemma: vento portante, Sense: 1
# Lemma: vento reale, Sense: 1
# Lemma: vento teso, Sense: 1
# Lemma: virare di prua, Sense: 1
# Lemma: zattera, Sense: 1
# Lemma: zinco, Sense: 1
#
# Newly Added Relations:
# Relation Type: antonym, Target Lemma: dentro, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: girare, Target Sense: 3
# Relation Type: has_hyperonym, Target Lemma: manovrare, Target Sense: 1
# Relation Type: near_synonym, Target Lemma: cogliere, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: avvolgere, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: manovrare, Target Sense: 2
# Relation Type: has_hyperonym, Target Lemma: uomo, Target Sense: 2
# Relation Type: has_hyponym, Target Lemma: radioabbonato, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: teleabbonato, Target Sense: 1
# Relation Type: be_in_state, Target Lemma: abbonato, Target Sense: 1
# Relation Type: role_agent, Target Lemma: abbonamento, Target Sense: 1
# Relation Type: near_synonym, Target Lemma: investimento, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: atto, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: abbordaggio intenzionale, Target Sense: 1
# Relation Type: xpos_near_synonym, Target Lemma: abbrivio, Target Sense: 2
# Relation Type: has_hyperonym, Target Lemma: manovrare, Target Sense: 1
# Relation Type: xpos_near_synonym, Target Lemma: abbrivare, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: movimento, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: impulso, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: abitatore, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: uomo, Target Sense: 2
# Relation Type: role_agent, Target Lemma: abolire, Target Sense: 2
# Relation Type: has_hyperonym, Target Lemma: abitatore, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: materiale, Target Sense: 2
# Relation Type: has_hyperonym, Target Lemma: ammalato, Target Sense: 1
# Relation Type: be_in_state, Target Lemma: accidioso, Target Sense: 1
# Relation Type: be_in_state, Target Lemma: sottomesso, Target Sense: 3
# Relation Type: has_hyperonym, Target Lemma: pensatore, Target Sense: 2
# Relation Type: has_holo_member, Target Lemma: academia, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: professore, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: ordigno, Target Sense: 2
# Relation Type: has_hyponym, Target Lemma: betatrone, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: sincrotrone, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: barcone, Target Sense: 1
# Relation Type: xpos_near_synonym, Target Lemma: accostare, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: manovra, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: aggettivo, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: uomo, Target Sense: 2
# Relation Type: has_hyponym, Target Lemma: pentito, Target Sense: 2
# Relation Type: be_in_state, Target Lemma: accusato, Target Sense: 1
# Relation Type: co_role, Target Lemma: accusatore, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: abitatore, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: roba, Target Sense: 2
# Relation Type: has_hyponym, Target Lemma: altura, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: mare a montoni, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: mare calmo, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: mare corto, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: mare di latte, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: mare grosso, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: mare incrociato, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: mare lungo, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: mare mosso, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: mare poco mosso, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: mare sporco, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: rough sea, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: insetto, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: nota, Target Sense: 7
# Relation Type: has_hyperonym, Target Lemma: movimento, Target Sense: 4
# Relation Type: has_hyperonym, Target Lemma: accolito, Target Sense: 2
# Relation Type: has_hyponym, Target Lemma: apostolo, Target Sense: 1
# Relation Type: role_agent, Target Lemma: parteggiare, Target Sense: 2
# Relation Type: has_hyperonym, Target Lemma: aeromobile, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: mezzo, Target Sense: 2
# Relation Type: has_hyponym, Target Lemma: aerobus, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: aerocisterna, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: aeropostale, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: aerorimorchiatore, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: aerosilurante, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: aerotaxi, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: aviogetto, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: bimotore, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: bireattore, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: bombardiere, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: caccia, Target Sense: 6
# Relation Type: has_hyponym, Target Lemma: cacciareattore, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: charter, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: convertiplano, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: jet, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: monoplano, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: quadrigetto, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: quadrimotore, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: trimotore, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: turboreattore, Target Sense: 2
# Relation Type: role, Target Lemma: avvitarsi, Target Sense: 1
# Relation Type: role_patient, Target Lemma: virare, Target Sense: 1
# Relation Type: role_instrument, Target Lemma: navigare, Target Sense: 2
# Relation Type: role_instrument, Target Lemma: rullare, Target Sense: 2
# Relation Type: role_instrument, Target Lemma: viaggiare, Target Sense: 1
# Relation Type: role_agent, Target Lemma: sorvolare, Target Sense: 2
# Relation Type: has_hyperonym, Target Lemma: ammalato, Target Sense: 1
# Relation Type: be_in_state, Target Lemma: afasico, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: uomo, Target Sense: 2
# Relation Type: be_in_state, Target Lemma: affamato, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: insaccato, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: atto, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: causare, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: abitatore, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: accolito, Target Sense: 2
# Relation Type: has_hyperonym, Target Lemma: succo, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: manovra, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: utensile, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: abitatore, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: nave, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: parte, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: albero di controvelaccino, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: albero di parrocchetto, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: albero di poppa, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: albero di trinchetto, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: albero di velaccino, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: mezzana, Target Sense: 1
# Relation Type: fuzzynym, Target Lemma: corretto, Target Sense: 3
# Relation Type: has_hyperonym, Target Lemma: bevanda, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: acquavite, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: bitter, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: cervogia, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: cocktail, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: cordiale, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: cuas, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: drink, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: grog, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: idromele, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: liquore, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: long_drink, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: ponce, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: sangria, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: sidro, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: vino, Target Sense: 1
# Relation Type: role, Target Lemma: alcolico, Target Sense: 2
# Relation Type: role_instrument, Target Lemma: inebriarsi, Target Sense: 1
# Relation Type: has_instance, Target Lemma: Bloody Mary, Target Sense: 1
# Relation Type: has_pertained, Target Lemma: alcoolico, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: vento costante, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: materiale, Target Sense: 2
# Relation Type: has_hyperonym, Target Lemma: uomo, Target Sense: 2
# Relation Type: be_in_state, Target Lemma: alluvionato, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: armato, Target Sense: 1
# Relation Type: has_holo_member, Target Lemma: alpini, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: altezza dell'acqua, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: altezza di una stella, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: altezza metacentrica, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: fondale, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: puntale, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: acque, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: liquore, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: abitatore, Target Sense: 1
# Relation Type: near_synonym, Target Lemma: comunicativo, Target Sense: 2
# Relation Type: state_of, Target Lemma: amichevole, Target Sense: 1
# Relation Type: derivation, Target Lemma: amichevolmente, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: manovrare, Target Sense: 2
# Relation Type: has_hyponym, Target Lemma: imbrogliare, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: utensile, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: ancora a fungo, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: ancora ad aratro, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: ancora Ammiragliato, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: ancora Danforth, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: ancora di rispetto, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: ancora galleggiante, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: ancora Hall, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: ancorotto, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: grappino, Target Sense: 2
# Relation Type: has_hyponym, Target Lemma: grappino, Target Sense: 1
# Relation Type: has_mero_part, Target Lemma: diamante, Target Sense: 2
# Relation Type: has_holo_location, Target Lemma: nave, Target Sense: 1
# Relation Type: role_patient, Target Lemma: salpare, Target Sense: 1
# Relation Type: role_instrument, Target Lemma: ancoraggio, Target Sense: 2
# Relation Type: xpos_near_synonym, Target Lemma: ancorarsi, Target Sense: 1
# Relation Type: xpos_near_synonym, Target Lemma: ormeggiare, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: manovra, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: andana, Target Sense: 2
# Relation Type: has_hyperonym, Target Lemma: abitatore, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: ancoraggio, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: andare alla deriva, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: navigare, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: partire, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: movimento, Target Sense: 2
# Relation Type: has_hyponym, Target Lemma: andatura al giardinetto, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: andatura al mascone, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: andatura alla cappa, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: andatura di bolina larga, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: andatura mura a dritta, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: andatura mura a sinistra, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: andatura, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: andatura, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: andatura, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: gonioanemometro, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: ferro, Target Sense: 3
# Relation Type: has_hyponym, Target Lemma: angolo di barra, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: angolo di deriva, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: angolo di sbandamento, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: angolo orario, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: bugna, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: declinazione magnetica, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: rilevamento, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: movimento, Target Sense: 4
# Relation Type: has_hyperonym, Target Lemma: morire, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: cappio del pescatore, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: gassa d'amante, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: gassa d'amante semplice, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: gassa spagnola, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: impalmatura, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: mezzocollo, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: nodo bandiera, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: nodo d'anguilla, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: nodo del barcaiolo, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: nodo del cappuccino, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: nodo del francescano, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: nodo dell'impiccato, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: nodo di ancorotto ganciato, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: nodo di bolina, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: nodo di bozza, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: nodo inglese, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: nodo margherita, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: nodo parlato semplice, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: nodo piano, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: nodo portoghese, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: nodo Savoia, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: nodo scorsoio semplice, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: nodo semplice, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: nodo vaccaio, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: nodo volante, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: pugno di scimmia, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: uomo, Target Sense: 2
# Relation Type: be_in_state, Target Lemma: ignoto, Target Sense: 1
# Relation Type: be_in_state, Target Lemma: sconosciuto, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: periodo_storico, Target Sense: 1
# Relation Type: has_pertained, Target Lemma: anteguerra, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: pressione atmosferica, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: accolito, Target Sense: 2
# Relation Type: be_in_state, Target Lemma: anticlericale, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: uomo, Target Sense: 2
# Relation Type: be_in_state, Target Lemma: anticonformismo, Target Sense: 1
# Relation Type: be_in_state, Target Lemma: strampalato, Target Sense: 1
# Relation Type: antonym, Target Lemma: democratico, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: uomo, Target Sense: 2
# Relation Type: be_in_state, Target Lemma: antidemocratico, Target Sense: 1
# Relation Type: fuzzynym, Target Lemma: mafia, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: commissione, Target Sense: 1
# Relation Type: has_pertained, Target Lemma: antimafia, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: mercante, Target Sense: 1
# Relation Type: antonym, Target Lemma: razzistico, Target Sense: 1
# Relation Type: state_of, Target Lemma: antirazzista, Target Sense: 1
# Relation Type: antonym, Target Lemma: schiavista, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: uomo, Target Sense: 2
# Relation Type: be_in_state, Target Lemma: abolizionista, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: accolito, Target Sense: 2
# Relation Type: be_in_state, Target Lemma: antisemita, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: dito, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: sito, Target Sense: 1
# Relation Type: near_synonym, Target Lemma: associato, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: uomo, Target Sense: 2
# Relation Type: has_hyponym, Target Lemma: accademico, Target Sense: 3
# Relation Type: has_hyponym, Target Lemma: assessore, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: centumviro, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: commissario, Target Sense: 2
# Relation Type: has_hyponym, Target Lemma: consigliere, Target Sense: 2
# Relation Type: has_hyponym, Target Lemma: decemviro, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: deviscio, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: frondista, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: gerosolomitano, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: lobbysta, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: onorevole, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: popolare, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: quadrumviro, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: squadrista, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: terrorista, Target Sense: 2
# Relation Type: has_hyponym, Target Lemma: terziario, Target Sense: 2
# Relation Type: has_hyponym, Target Lemma: triumviro, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: zulu, Target Sense: 1
# Relation Type: has_holo_member, Target Lemma: gruppo, Target Sense: 2
# Relation Type: be_in_state, Target Lemma: appartenente, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: veliero, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: abitatore, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: abitatore, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: abitatore, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: albore, Target Sense: 3
# Relation Type: has_hyponym, Target Lemma: melangolo, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: melarancio, Target Sense: 1
# Relation Type: has_holo_member, Target Lemma: agrumi, Target Sense: 1
# Relation Type: co_role, Target Lemma: arancia, Target Sense: 1
# Relation Type: near_synonym, Target Lemma: impenetrabile, Target Sense: 2
# Relation Type: near_synonym, Target Lemma: scuro, Target Sense: 4
# Relation Type: xpos_near_synonym, Target Lemma: rompicapo, Target Sense: 2
# Relation Type: antonym, Target Lemma: comprensibile, Target Sense: 1
# Relation Type: antonym, Target Lemma: palese, Target Sense: 1
# Relation Type: derivation, Target Lemma: incomprensibilmente, Target Sense: 1
# Relation Type: liable_to, Target Lemma: apprendere, Target Sense: 1
# Relation Type: liable_to, Target Lemma: mettere_in_chiaro, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: fenomeno_naturale, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: abitatore, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: bava di vento, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: bufera, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: groppo, Target Sense: 2
# Relation Type: has_hyponym, Target Lemma: vento a raffiche, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: vento al traverso, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: vento apparente, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: vento contrario, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: vento costante, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: vento di prua, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: vento dominante, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: vento favorevole, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: vento in poppa, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: vento locale, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: vento portante, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: vento reale, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: vento teso, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: accolito, Target Sense: 2
# Relation Type: has_hyperonym, Target Lemma: composizione_musicale, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: insieme, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: armamento di fortuna, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: attrezzare, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: equipaggiare, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: abitatore, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: accreditamento, Target Sense: 2
# Relation Type: xpos_near_synonym, Target Lemma: arruolamento, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: ammalato, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: lavoratore, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: acconciatore, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: accordatore, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: arazziere, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: argentiere, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: armaiolo, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: arrotino, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: battirame, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: birraio, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: bottaro, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: bronzista, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: calzolaio, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: camiciaio, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: canapaio, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: cappellaio, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: cardatore, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: carradore, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: cartaio, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: cassaio, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: ceraiolo, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: ceramista, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: cesellatore, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: cestaio, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: ciabattino, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: cioccolataio, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: coloritore, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: coltellinaio, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: conciatore, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: confettiere, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: corallaio, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: cordaio, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: corniciaio, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: cucitore, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: cucitrice, Target Sense: 3
# Relation Type: has_hyponym, Target Lemma: decoratore, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: doratore, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: ebanista, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: fabbro, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: forbiciaio, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: forgiatore, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: formaggiaio, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: fornaio, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: gelataio, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: gessaio, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: gioielliere, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: guantaio, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: incastonatore, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: intagliatore, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: intarsiatore, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: lanaiolo, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: lapicida, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: legnaiolo, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: linaiolo, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: litografo, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: liutaio, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: magnano, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: maniscalco, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: marmista, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: materassaio, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: medaglista, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: merlettaia, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: mobiliere, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: mugnaio, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: occhialaio, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: ombrellaio, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: orefice, Target Sense: 2
# Relation Type: has_hyponym, Target Lemma: orologiaio, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: panieraio, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: pastaio, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: pasticciere, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: pellaio, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: pellettiere, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: pellicciaio, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: profumiere, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: ramaio, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: restauratore, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: ricamatrice, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: legatore, Target Sense: 2
# Relation Type: has_hyponym, Target Lemma: saponiere, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: sarto, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: seggiolaio, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: sellaio, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: setaiolo, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: smaltatore, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: staderaio, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: stipettaio, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: tamburaio, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: tappezziere, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: tessitore, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: tintore, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: tipografo, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: valigiaio, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: vasaio, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: vetraio, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: zincografo, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: zincotipista, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: zoccolaio, Target Sense: 1
# Relation Type: role_agent, Target Lemma: lavoro, Target Sense: 1
# Relation Type: role_agent, Target Lemma: mestiere, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: uomo, Target Sense: 2
# Relation Type: be_in_state, Target Lemma: assente, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: assicurare la bandiera, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: assicurazione della merce, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: polizza di carico, Target Sense: 1
# Relation Type: state_of, Target Lemma: assuntore, Target Sense: 2
# Relation Type: has_hyperonym, Target Lemma: accolito, Target Sense: 2
# Relation Type: has_hyperonym, Target Lemma: attributo, Target Sense: 1
# Relation Type: derivation, Target Lemma: astrattamente, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: fisico, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: quartiere, Target Sense: 3
# Relation Type: has_hyponym, Target Lemma: superattico, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: atto, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: nautica, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: accolta, Target Sense: 1
# Relation Type: antonym, Target Lemma: passivo, Target Sense: 2
# Relation Type: has_hyperonym, Target Lemma: forma_verbale, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: filmato, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: trasmissione, Target Sense: 4
# Relation Type: has_hyperonym, Target Lemma: abitatore, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: abitatore, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: colore, Target Sense: 2
# Relation Type: is_extension_of, Target Lemma: avana, Target Sense: 2
# Relation Type: has_hyperonym, Target Lemma: punta, Target Sense: 5
# Relation Type: has_hyponym, Target Lemma: avaria generale, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: avaria particolare, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: osso, Target Sense: 2
# Relation Type: xpos_near_synonym, Target Lemma: partecipazione, Target Sense: 4
# Relation Type: has_hyperonym, Target Lemma: atto, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: allarme, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: avviso, Target Sense: 2
# Relation Type: has_hyponym, Target Lemma: uomo in mare, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: avvisatore marittimo, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: manovrare, Target Sense: 2
# Relation Type: has_hyperonym, Target Lemma: colore, Target Sense: 2
# Relation Type: be_in_state, Target Lemma: azzurro, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: sportivo, Target Sense: 1
# Relation Type: be_in_state, Target Lemma: azzurro, Target Sense: 2
# Relation Type: has_hyperonym, Target Lemma: bacino, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: bacino di allestimento, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: bacino di carenaggio, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: bacino galleggiante, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: scalo d'alaggio, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: collo, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: barcone, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: parte, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: area, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: cavallo, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: agricoltore, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: colletto_bianco, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: colletto_bianco, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: guidone, Target Sense: 2
# Relation Type: has_hyperonym, Target Lemma: barca, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: abitatore, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: parte, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: strumento, Target Sense: 4
# Relation Type: co_instrument_agent, Target Lemma: bassista, Target Sense: 1
# Relation Type: near_synonym, Target Lemma: piroscafo, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: abitatore, Target Sense: 1
# Relation Type: near_synonym, Target Lemma: S., Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: uomo, Target Sense: 2
# Relation Type: be_in_state, Target Lemma: beato, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: abitatore, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: insieme, Target Sense: 1
# Relation Type: has_meronym, Target Lemma: oggetto, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: minuto, Target Sense: 4
# Relation Type: has_hyperonym, Target Lemma: abitatore, Target Sense: 1
# Relation Type: derivation, Target Lemma: favorevole, Target Sense: 1
# Relation Type: manner_of, Target Lemma: decantare, Target Sense: 2
# Relation Type: has_hyperonym, Target Lemma: roba, Target Sense: 2
# Relation Type: has_hyperonym, Target Lemma: abitatore, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: nave militare, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: colore, Target Sense: 2
# Relation Type: antonym, Target Lemma: moro, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: uomo, Target Sense: 2
# Relation Type: be_in_state, Target Lemma: biondo, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: abitatore, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: stanghetta, Target Sense: 1
# Relation Type: has_holo_part, Target Lemma: violino, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: bicchiere, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: sportivo, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: uomo, Target Sense: 2
# Relation Type: has_hyperonym, Target Lemma: abitatore, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: locale, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: abitatore, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: locale, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: abitatore, Target Sense: 1
# Relation Type: has_hyponym, Target Lemma: bolletta di consegna, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: abitatore, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: uomo, Target Sense: 2
# Relation Type: be_in_state, Target Lemma: bonario, Target Sense: 1
# Relation Type: be_in_state, Target Lemma: soave, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: accolito, Target Sense: 2
# Relation Type: has_hyponym, Target Lemma: sopravvento, Target Sense: 1
# Relation Type: near_synonym, Target Lemma: nave, Target Sense: 1
# Relation Type: has_hyperonym, Target Lemma: uomo, Target Sense: 2
# ...
#                 <TARGET_WM ID="30374" PART_OF_SPEECH="N" LEMMA="tunica" SENSE="2" GLOSS="qualsiasi abito di tale foggia." />
#             </RELATION>
# <RELATION TYPE="has_hyponym" ID="10" INV_ID="10">
#                 <TARGET_WM ID="5509" PART_OF_SPEECH="N" LEMMA="uniforme" SENSE="1" GLOSS="uniforme  abito comune a militari  collegiali." />
#             </RELATION>
# <RELATION TYPE="has_hyponym" ID="10" INV_ID="10">
#                 <TARGET_WM ID="6893" PART_OF_SPEECH="N" LEMMA="vestaglietta" SENSE="1" GLOSS="abito femminile estivo e leggero  da casa o da mare." />
#             </RELATION>
# <RELATION TYPE="has_hyponym" ID="10" INV_ID="10">
#                 <TARGET_WM ID="606" PART_OF_SPEECH="N" LEMMA="veste_da_camera" SENSE="1" GLOSS="indumento da camera  maschile o femminile.">
#                     <RFEATURES REVERSED="T" />
#                 </TARGET_WM>
#             </RELATION>
# <RELATION TYPE="has_hyponym" ID="10" INV_ID="10">
#                 <TARGET_WM ID="20841" PART_OF_SPEECH="N" LEMMA="zimarra" SENSE="1" GLOSS="veste di origine spagnola  con maniche e bavero molto ampi  usata un tempo come soprabito." />
#             </RELATION>
# <RELATION TYPE="has_holonym" ID="12" INV_ID="12">
#                 <TARGET_WM ID="2436" PART_OF_SPEECH="N" LEMMA="abbigliamento" SENSE="1" GLOSS="il complesso delle vesti di una persona.">
#                     <RFEATURES REVERSED="T" />
#                 </TARGET_WM>
#             </RELATION>
# <RELATION TYPE="has_holonym" ID="12" INV_ID="12">
#                 <TARGET_WM ID="17106" PART_OF_SPEECH="N" LEMMA="corredo" SENSE="1" GLOSS="l'insieme di abiti  biancheria e oggetti personali di una sposa  una novizia  un collegiale e sim." />
#             </RELATION>
# <RELATION TYPE="has_mero_part" ID="19" INV_ID="19">
#                 <TARGET_WM ID="5520" PART_OF_SPEECH="N" LEMMA="abbottonatura" SENSE="3" GLOSS="parte di un abito in cui sono cuciti i bottoni." />
#             </RELATION>
# <RELATION TYPE="has_mero_part" ID="19" INV_ID="19">
#                 <TARGET_WM ID="30261" PART_OF_SPEECH="N" LEMMA="accollatura" SENSE="1" />
#             </RELATION>
# <RELATION TYPE="has_mero_part" ID="19" INV_ID="19">
#                 <TARGET_WM ID="26293" PART_OF_SPEECH="N" LEMMA="banda" SENSE="4" GLOSS="striscia di stoffa applicata ad un abito  per lo più di colore diverso" />
#             </RELATION>
# <RELATION TYPE="has_mero_part" ID="19" INV_ID="19">
#                 <TARGET_WM ID="22589" PART_OF_SPEECH="N" LEMMA="bavero" SENSE="1" GLOSS="parte del mantello o del vestito che sta intorno al collo e si porta per lo più ripiegata." />
#             </RELATION>
# <RELATION TYPE="has_mero_part" ID="19" INV_ID="19">
#                 <TARGET_WM ID="5288" PART_OF_SPEECH="N" LEMMA="collo" SENSE="2" GLOSS="la parte del vestito che sta attorno al collo." />
#             </RELATION>
# <RELATION TYPE="has_mero_part" ID="19" INV_ID="19">
#                 <TARGET_WM ID="3443" PART_OF_SPEECH="N" LEMMA="corpino" SENSE="1" />
#             </RELATION>
# <RELATION TYPE="has_mero_part" ID="19" INV_ID="19">
#                 <TARGET_WM ID="28090" PART_OF_SPEECH="N" LEMMA="davantino" SENSE="1" />
#             </RELATION>
# <RELATION TYPE="has_mero_part" ID="19" INV_ID="19">
#                 <TARGET_WM ID="22247" PART_OF_SPEECH="N" LEMMA="gorgiera" SENSE="1" GLOSS="parte delle antiche armature poste a protezione della gola">
#                     <RFEATURES REVERSED="T" />
#                 </TARGET_WM>
#             </RELATION>
# <RELATION TYPE="has_mero_part" ID="19" INV_ID="19">
#                 <TARGET_WM ID="20557" PART_OF_SPEECH="N" LEMMA="manica" SENSE="1" />
#             </RELATION>
# <RELATION TYPE="has_mero_part" ID="19" INV_ID="19">
#                 <TARGET_WM ID="13588" PART_OF_SPEECH="N" LEMMA="orlatura" SENSE="2" GLOSS="parte estrema di un abito." />
#             </RELATION>
# <RELATION TYPE="has_mero_part" ID="19" INV_ID="19">
#                 <TARGET_WM ID="12483" PART_OF_SPEECH="N" LEMMA="petto" SENSE="4" GLOSS="parte anteriore di un indumento corrispondente al petto" />
#             </RELATION>
# <RELATION TYPE="has_mero_part" ID="19" INV_ID="19">
#                 <TARGET_WM ID="29569" PART_OF_SPEECH="N" LEMMA="pettorina" SENSE="1" GLOSS="lembo di tessuto usato dalle donne per coprire il seno">
#                     <RFEATURES REVERSED="T" />
#                 </TARGET_WM>
#             </RELATION>
# <RELATION TYPE="has_mero_part" ID="19" INV_ID="19">
#                 <TARGET_WM ID="31581" PART_OF_SPEECH="N" LEMMA="scollatura" SENSE="3" GLOSS="taglio  negli abiti femminili  che lascia scoperta in modo più o meno ampio la parte superiore del petto e /o la schiena." />
#             </RELATION>
# <RELATION TYPE="has_mero_part" ID="19" INV_ID="19">
#                 <TARGET_WM ID="19081" PART_OF_SPEECH="N" LEMMA="spalla" SENSE="3" GLOSS="parte di un indumento che ricopre la spalla." />
#             </RELATION>
# <RELATION TYPE="has_mero_part" ID="19" INV_ID="19">
#                 <TARGET_WM ID="11927" PART_OF_SPEECH="N" LEMMA="strascico" SENSE="2" />
#             </RELATION>
# <RELATION TYPE="has_mero_madeof" ID="21" INV_ID="21">
#                 <TARGET_WM ID="24273" PART_OF_SPEECH="N" LEMMA="cotone" SENSE="1" GLOSS="fibra tessile ricavata dalla pianta omonima e anche il tessuto ricavato da tale fibra." />
#             </RELATION>
# <RELATION TYPE="has_mero_madeof" ID="21" INV_ID="21">
#                 <TARGET_WM ID="4139" PART_OF_SPEECH="N" LEMMA="cuoio" SENSE="1" GLOSS="pelle di animale conciata per fare borse  valigie  cinture ecc..  pelle di animale conciata" />
#             </RELATION>
# <RELATION TYPE="has_mero_madeof" ID="21" INV_ID="21">
#                 <TARGET_WM ID="20881" PART_OF_SPEECH="N" LEMMA="lana" SENSE="1" GLOSS="fibra tessile ricavata dalla tosatura di ovini  caprini e alcuni camelidi  e anche il tessuto ottenuto da tale fibra." />
#             </RELATION>
# <RELATION TYPE="has_mero_madeof" ID="21" INV_ID="21">
#                 <TARGET_WM ID="9923" PART_OF_SPEECH="N" LEMMA="lino" SENSE="2" GLOSS="pregiata fibra tessile  ricavata dalla pianta omonima." />
#             </RELATION>
# <RELATION TYPE="has_mero_madeof" ID="21" INV_ID="21">
#                 <TARGET_WM ID="2916" PART_OF_SPEECH="N" LEMMA="nylon" SENSE="1" GLOSS="fibra sintetica uasta nell'industria tessile  nella produzione di laminati e di oggetti vari.">
#                     <RFEATURES REVERSED="T" />
#                 </TARGET_WM>
#             </RELATION>
# <RELATION TYPE="has_mero_madeof" ID="21" INV_ID="21">
#                 <TARGET_WM ID="5219" PART_OF_SPEECH="N" LEMMA="seta" SENSE="2" GLOSS="tessuto morbido e lucente ricavato dalla fibra che si ottiene dal bozzolo dei bachi da seta." />
#             </RELATION>
# <RELATION TYPE="has_mero_madeof" ID="21" INV_ID="21">
#                 <TARGET_WM ID="4550" PART_OF_SPEECH="N" LEMMA="stoffa" SENSE="1" GLOSS="tessuto di lana  cotone e simili per fare abiti  tappezzerie o altro.  il manufatto ricavato dalla tessitura." />
#             </RELATION>
# <RELATION TYPE="has_mero_location" ID="23" INV_ID="23">
#                 <TARGET_WM ID="15727" PART_OF_SPEECH="N" LEMMA="bottone" SENSE="1" GLOSS="piccolo disco di materiale vario che serve per allacciare le parti di un indumento e talvolta per ornare" />
#             </RELATION>
# <RELATION TYPE="has_mero_location" ID="23" INV_ID="23">
#                 <TARGET_WM ID="2501" PART_OF_SPEECH="N" LEMMA="spacco" SENSE="3" GLOSS="apertura realizzata negli abiti per comodità o eleganza.">
#                     <RFEATURES REVERSED="T" />
#                 </TARGET_WM>
#             </RELATION>
# <RELATION TYPE="has_mero_location" ID="23" INV_ID="23">
#                 <TARGET_WM ID="4596" PART_OF_SPEECH="N" LEMMA="sparato" SENSE="1" />
#             </RELATION>
# <RELATION TYPE="role_patient" ID="28" INV_ID="28">
#                 <TARGET_WM ID="33970" PART_OF_SPEECH="V" LEMMA="scollare" SENSE="1" />
#             </RELATION>
# <RELATION TYPE="role_patient" ID="28" INV_ID="28">
#                 <TARGET_WM ID="37675" PART_OF_SPEECH="V" LEMMA="scucire" SENSE="1" />
#             </RELATION>
# <RELATION TYPE="role_patient" ID="28" INV_ID="28">
#                 <TARGET_WM ID="33046" PART_OF_SPEECH="V" LEMMA="stirare" SENSE="2" GLOSS="spianare le pieghe ai vestiti e alla biancheria col ferro da stiro.">
#                     <RFEATURES REVERSED="T" />
#                 </TARGET_WM>
#             </RELATION>
# Lemma: viennese, Sense: 1
# <RELATION TYPE="has_hyperonym" ID="8" INV_ID="8">
#                 <TARGET_WM ID="22292" PART_OF_SPEECH="N" LEMMA="abitatore" SENSE="1" GLOSS="chi abita in un luogo." />
#             </RELATION>
# Lemma: vietnamita, Sense: 1
# <RELATION TYPE="has_hyperonym" ID="8" INV_ID="8">
#                 <TARGET_WM ID="22292" PART_OF_SPEECH="N" LEMMA="abitatore" SENSE="1" GLOSS="chi abita in un luogo." />
#             </RELATION>
# Lemma: vigilante, Sense: 1
# <RELATION TYPE="has_hyperonym" ID="8" INV_ID="8">
#                 <TARGET_WM ID="23922" PART_OF_SPEECH="N" LEMMA="agente" SENSE="1" GLOSS="chi compie determinati servizi per conto di altri." />
#             </RELATION>
# <RELATION TYPE="has_hyponym" ID="10" INV_ID="10">
#                 <TARGET_WM ID="14114" PART_OF_SPEECH="N" LEMMA="guardia_notturna" SENSE="1" GLOSS="guardia notturna in servizio negli abitati.">
#                     <RFEATURES REVERSED="T" />
#                 </TARGET_WM>
#             </RELATION>
# Lemma: villano, Sense: 2
# <RELATION TYPE="near_synonym" ID="1" INV_ID="1">
#                 <TARGET_WM ID="18494" PART_OF_SPEECH="N" LEMMA="rustico" SENSE="3" GLOSS="chi coltiva la terra   chi lavora la terra">
#                     <RFEATURES REVERSED="T" />
#                 </TARGET_WM>
#             </RELATION>
# <RELATION TYPE="antonym" ID="5" INV_ID="5">
#                 <TARGET_WM ID="15839" PART_OF_SPEECH="N" LEMMA="cittadino" SENSE="2" GLOSS="chi abita in città">
#                     <RFEATURES REVERSED="T" />
#                 </TARGET_WM>
#             </RELATION>
# <RELATION TYPE="has_hyperonym" ID="8" INV_ID="8">
#                 <TARGET_WM ID="863" PART_OF_SPEECH="N" LEMMA="uomo" SENSE="2" GLOSS="essere umano">
#                     <RFEATURES REVERSED="T" />
#                 </TARGET_WM>
#             </RELATION>
# <RELATION TYPE="role_agent" ID="81" INV_ID="81">
#                 <TARGET_WM ID="33602" PART_OF_SPEECH="V" LEMMA="essere_vivo" SENSE="1" GLOSS="essere in vita  detto di esseri animati." />
#             </RELATION>
# <RELATION TYPE="role_agent" ID="81" INV_ID="81">
#                 <TARGET_WM ID="40431" PART_OF_SPEECH="V" LEMMA="lavorare" SENSE="1" GLOSS="eseguire un lavoro fisico o mentale." />
#             </RELATION>
# Lemma: vinciano, Sense: 1
# <RELATION TYPE="has_hyperonym" ID="8" INV_ID="8">
#                 <TARGET_WM ID="22292" PART_OF_SPEECH="N" LEMMA="abitatore" SENSE="1" GLOSS="chi abita in un luogo.">
#                     <RFEATURES REVERSED="T" />
#                 </TARGET_WM>
#             </RELATION>
# Lemma: violetto, Sense: 1
# <RELATION TYPE="has_hyperonym" ID="8" INV_ID="8">
#                 <TARGET_WM ID="5593" PART_OF_SPEECH="N" LEMMA="colore" SENSE="2" GLOSS="ogni elemento dello spettro di luce">
#                     <RFEATURES REVERSED="T" />
#                 </TARGET_WM>
#             </RELATION>
# Lemma: virare, Sense: 1
# <RELATION TYPE="has_hyponym" ID="10" INV_ID="10">
#                 <TARGET_WM ID="33737" PART_OF_SPEECH="V" LEMMA="strambare" SENSE="1" GLOSS="Usato comunemente per indicare su un veliero l'insieme delle manovre per virare di bordo in poppa. La manovra richiede una rotazione della prua fino a cambiare le mura (cioè il lato dal quale si riceve il vento) passando con il vento da poppa" />
#             </RELATION>
# <RELATION TYPE="has_hyponym" ID="10" INV_ID="10">
#                 <TARGET_WM ID="51541" PART_OF_SPEECH="V" LEMMA="virare di prua" SENSE="1" GLOSS="manovrare per un cambio di bordo da prua." />
#             </RELATION>
# Lemma: virata, Sense: 1
# <RELATION TYPE="xpos_near_synonym" ID="2" INV_ID="2">
#                 <TARGET_WM ID="51541" PART_OF_SPEECH="V" LEMMA="virare di prua" SENSE="1" GLOSS="manovrare per un cambio di bordo da prua." />
#             </RELATION>
# <RELATION TYPE="has_hyperonym" ID="8" INV_ID="8">
#                 <TARGET_WM ID="5697" PART_OF_SPEECH="N" LEMMA="manovra" SENSE="1" GLOSS="serie di operazioni  movimenti  e simili volti al conseguimento di un risultato spec. di tipo pratico" />
#             </RELATION>
# Lemma: virginale, Sense: 1
# <RELATION TYPE="has_hyperonym" ID="8" INV_ID="8">
#                 <TARGET_WM ID="13034" PART_OF_SPEECH="N" LEMMA="strumento" SENSE="4" GLOSS="qualsiasi strumento  ad arco a corda a fiato a percussione ecc. atto a produrre suoni musicali.">
#                     <RFEATURES REVERSED="T" />
#                 </TARGET_WM>
#             </RELATION>
# Lemma: vivere, Sense: 2
# <RELATION TYPE="has_hyperonym" ID="8" INV_ID="8">
#                 <TARGET_WM ID="4759" PART_OF_SPEECH="N" LEMMA="necessario" SENSE="1" GLOSS="I beni indispensabili come il cibo o la casa.">
#                     <RFEATURES REVERSED="T" />
#                 </TARGET_WM>
#             </RELATION>
# Lemma: vocale, Sense: 1
# <RELATION TYPE="has_hyperonym" ID="8" INV_ID="8">
#                 <TARGET_WM ID="17159" PART_OF_SPEECH="N" LEMMA="fonema" SENSE="1" GLOSS="unità minima distintiva di significato">
#                     <RFEATURES REVERSED="T" />
#                 </TARGET_WM>
#             </RELATION>
# <RELATION TYPE="has_hyponym" ID="10" INV_ID="10">
#                 <TARGET_WM ID="5166" PART_OF_SPEECH="N" LEMMA="dittongo" SENSE="1" GLOSS="unione di due vocali  pronunziate in una sola sillaba">
#                     <RFEATURES REVERSED="T" />
#                 </TARGET_WM>
#             </RELATION>
# <RELATION TYPE="has_hyponym" ID="10" INV_ID="10">
#                 <TARGET_WM ID="18914" PART_OF_SPEECH="N" LEMMA="monottongo" SENSE="1" GLOSS="vocale risultante da monottongazione">
#                     <RFEATURES REVERSED="T" />
#                 </TARGET_WM>
#             </RELATION>
# Lemma: volere, Sense: 2
# <RELATION TYPE="has_hyperonym" ID="8" INV_ID="8">
#                 <TARGET_WM ID="11412" PART_OF_SPEECH="N" LEMMA="determinazione" SENSE="1" GLOSS="il determinare">
#                     <RFEATURES REVERSED="T" />
#                 </TARGET_WM>
#             </RELATION>
# Lemma: volpino, Sense: 1
# <RELATION TYPE="has_hyperonym" ID="8" INV_ID="8">
#                 <TARGET_WM ID="22196" PART_OF_SPEECH="N" LEMMA="cane" SENSE="1" GLOSS="animale domestico molto comune  diffuso in tutto il mondo  usato per la caccia  la difesa  nella pastorizia  e come animale da compagnia.">
#                     <RFEATURES REVERSED="T" />
#                 </TARGET_WM>
#             </RELATION>
# <RELATION TYPE="has_hyperonym" ID="8" INV_ID="8">
#                 <TARGET_WM ID="16268" PART_OF_SPEECH="N" LEMMA="specie" SENSE="2" GLOSS="gruppo tassonomico  ripartizione usata in biologia" />
#             </RELATION>
# Lemma: volpino, Sense: 1
# <RELATION TYPE="has_hyperonym" ID="8" INV_ID="8">
#                 <TARGET_WM ID="22196" PART_OF_SPEECH="N" LEMMA="cane" SENSE="1" GLOSS="animale domestico molto comune  diffuso in tutto il mondo  usato per la caccia  la difesa  nella pastorizia  e come animale da compagnia.">
#                     <RFEATURES REVERSED="T" />
#                 </TARGET_WM>
#             </RELATION>
# <RELATION TYPE="has_hyperonym" ID="8" INV_ID="8">
#                 <TARGET_WM ID="16268" PART_OF_SPEECH="N" LEMMA="specie" SENSE="2" GLOSS="gruppo tassonomico  ripartizione usata in biologia" />
#             </RELATION>
# Lemma: vuoto, Sense: 3
# <RELATION TYPE="has_hyperonym" ID="8" INV_ID="8">
#                 <TARGET_WM ID="27226" PART_OF_SPEECH="N" LEMMA="spazio" SENSE="1" GLOSS="entità indefinita e illimitata in cui stanno i corpi." />
#             </RELATION>
# Lemma: xenofobo, Sense: 1
# <RELATION TYPE="has_hyperonym" ID="8" INV_ID="8">
#                 <TARGET_WM ID="863" PART_OF_SPEECH="N" LEMMA="uomo" SENSE="2" GLOSS="essere umano" />
#             </RELATION>
# <RELATION TYPE="be_in_state" ID="40" INV_ID="40">
#                 <TARGET_WM ID="41318" PART_OF_SPEECH="AG" LEMMA="xenofobo" SENSE="1" GLOSS="detto di chi odia tutto ciò che è straniero." />
#             </RELATION>

# %%
def load_csv_data(csv_file_path):
    reference = {}
    with open(csv_file_path, mode='r', newline='', encoding='utf-8') as csvfile:
        reader = csv.DictReader(csvfile, delimiter=';')
        for row in reader:
            iwn_lemma = row['Literal Lemma']
            iwn_sense = row.get('IWN sense', 'N/A')
            mari_lemma = row['Literal Lemma']
            mari_sense = row.get('MariT sense', 'N/A')
            reference[(iwn_lemma, iwn_sense)] = (mari_lemma, mari_sense)
    return reference

def find_mariterm_synset(root, lemma, sense):
    """Utility function to find a MariTerm synset by lemma and sense."""
    for wm in root.findall('.//WORD_MEANING'):
        literal = wm.find('.//LITERAL')
        if literal is not None and literal.get('LEMMA') == lemma and literal.get('SENSE') == sense:
            return wm
    return None

def insert_after(parent, new_element, after_element):
    """Inserts new_element in parent right after after_element."""
    found = False
    for i, elem in enumerate(parent):
        if elem == after_element:
            found = True
            parent.insert(i + 1, new_element)
            break
    if not found:
        parent.append(new_element)

def ensure_plugin_links(wm):
    """Ensure the <PLUG-IN_LINKS/> tag is present for synsets that don't have it."""
    plugin_links = wm.find('.//PLUG-IN_LINKS')
    if plugin_links is None:
        internal_links = wm.find('.//INTERNAL_LINKS')
        empty_plugin_links = ET.Element('PLUG-IN_LINKS')
        if internal_links is not None:
            insert_after(wm, empty_plugin_links, internal_links)
        else:
            wm.append(empty_plugin_links)
        print(f"Added empty PLUG-IN_LINKS for Lemma={wm.find('.//LITERAL').get('LEMMA')}, Sense={wm.find('.//LITERAL').get('SENSE')}")

def add_plugins(iwn_root, mariterm_filtered_root, mariterm_original_root, reference, newly_added_relations_info):
    relation_type_mapping = {
        "plug-synonym": "1",
        "plug-near_synonym": "2",
        "plug-has_hyperonym": "3",
        "plug-has_hyponym": "4",
    }

    for wm in iwn_root.findall('.//WORD_MEANING'):
        lemma_element = wm.find('.//LITERAL')
        lemma = lemma_element.get('LEMMA') if lemma_element is not None else None
        sense = lemma_element.get('SENSE') if lemma_element is not None else None

        if not lemma or not sense:
            continue

        mari_synset = reference.get((lemma, sense))
        if not mari_synset:
            ensure_plugin_links(wm)
            continue

        mari_lemma, mari_sense = mari_synset
        mariterm_synset = find_mariterm_synset(mariterm_filtered_root, mari_lemma, mari_sense)
        if mariterm_synset is None:
            mariterm_synset = find_mariterm_synset(mariterm_original_root, mari_lemma, mari_sense)

        if mariterm_synset is not None:
            mariterm_id = mariterm_synset.get('ID')
            literals = [lit.get('LEMMA') for lit in mariterm_synset.findall('.//LITERAL')]
            literals_str = ','.join(literals)

            # Check if a PLUG-IN LINKS section already exists
            plugin_links = wm.find('.//PLUG-IN_LINKS')
            if plugin_links is None:
                plugin_links = ET.Element('PLUG-IN_LINKS')
                internal_links = wm.find('.//INTERNAL_LINKS')
                if internal_links is not None:
                    insert_after(wm, plugin_links, internal_links)
                else:
                    wm.append(plugin_links)

            # Ensure no duplicates for plug-synonym
            if not any(rel.find('.//TARGET_WM').get('ID') == f"{mariterm_id}#{literals_str}" for rel in plugin_links.findall('.//RELATION')):
                plug_synonym = ET.SubElement(plugin_links, 'RELATION', TYPE="plug-synonym", ID="1", INV_ID="1")
                ET.SubElement(plug_synonym, 'TARGET_WM', ID=f"{mariterm_id}#{literals_str}")
                print(f"Added PLUG-IN LINK with target {mariterm_id}#{literals_str} for Lemma={lemma}, Sense={sense}.")

            # Iterate over newly added relations
            for relation_info in newly_added_relations_info:
                rel_type, lemma, sense = relation_info  # Directly unpack the tuple
                print(f"Processing new relation: Type={rel_type}, Lemma={lemma}, Sense={sense}")

                # Only process eligible relation types
                if rel_type in ['near_synonym', 'has_hyperonym', 'has_hyponym']:
                    print(f"Relation type {rel_type} is eligible for plug-in.")

                    # Look for the corresponding MariTerm synset
                    mari_rel_synset = find_mariterm_synset(mariterm_filtered_root, lemma, sense)
                    if mari_rel_synset is None:
                        print(f"Target Lemma={lemma}, Sense={sense} not found in filtered MariTerm. Checking original MariTerm.")
                        mari_rel_synset = find_mariterm_synset(mariterm_original_root, lemma, sense)

                    if mari_rel_synset is not None:
                        # Construct the target MariTerm ID using PART_OF_SPEECH and ID
                        # Extract PART_OF_SPEECH and ID from the mari_rel_synset
                        part_of_speech = mari_rel_synset.get('PART_OF_SPEECH')
                        id_part = mari_rel_synset.get('ID')

                        # Ensure the PART_OF_SPEECH is not duplicated
                        if id_part.startswith(f"{part_of_speech}#"):
                            target_mariterm_id = id_part  # Use the ID directly if it already includes the POS
                        else:
                            target_mariterm_id = f"{part_of_speech}#{id_part}"  # Otherwise, concatenate them

                        print(f"Constructed Target MariTerm ID: {target_mariterm_id}")

                        # Now retrieve the corresponding WORD_MEANING synset in the original MariTerm to get literals
                        word_meaning_synset = find_mariterm_synset(mariterm_original_root, target_mariterm_id.split('#')[1], sense)

                        # Retrieve literals if the synset is found
                        if word_meaning_synset is not None:
                            literals = [lit.get('LEMMA') for lit in word_meaning_synset.findall('.//LITERAL')]
                            literals_str = ','.join(literals)
                            print(f"Retrieved literals: {literals_str}")
                        else:
                            literals_str = lemma  # Fallback to using the target lemma if no literals are found
                            print(f"Fallback to using target lemma: {literals_str}")
                    
                        # Add the plug-in relation
                        plug_relation_type = f"plug-{rel_type}"
                        plug_relation_id = relation_type_mapping[plug_relation_type]
                        plug_relation = ET.SubElement(plugin_links, 'RELATION', TYPE=plug_relation_type, ID=plug_relation_id, INV_ID=plug_relation_id)
                        ET.SubElement(plug_relation, 'TARGET_WM', ID=f"{target_mariterm_id}#{literals_str}")
                        print(f"Added {plug_relation_type} for Lemma={lemma}, Sense={sense} targeting {lemma} with MariTerm ID={target_mariterm_id}#{literals_str}.")
                    else:
                        print(f"Target Lemma={lemma}, Sense={sense} not found in MariTerm.")
                else:
                    print(f"Relation type {rel_type} is not eligible for plug-in.")


def save_pretty_xml(tree, xml_file_path):
    # Pretty-print the XML with proper formatting
    rough_string = ET.tostring(tree.getroot(), 'utf-8')
    reparsed = minidom.parseString(rough_string)
    
    # Custom cleanup to remove excessive whitespace
    pretty_xml = "\n".join([line for line in reparsed.toprettyxml(indent="    ").splitlines() if line.strip()])

    with open(xml_file_path, 'w', encoding='utf-8') as f:
        f.write(pretty_xml)
    print(f"Pretty XML file saved to {xml_file_path}")

# Load the necessary files
iwn_root = ET.parse(plug_att).getroot()
mariterm_filtered_root = ET.parse(filt_mart).getroot()
mariterm_original_root = ET.parse(MariT).getroot()

# Load the CSV data
reference = load_csv_data(breakdown_csv)

# Add PLUG-IN LINKS for all relevant synsets
add_plugins(iwn_root, mariterm_filtered_root, mariterm_original_root, reference, newly_added_relations_info)

# Ensure all synsets have a <PLUG-IN_LINKS/> section, even if it's empty
ensure_plugin_links(iwn_root)

# Save the modified XML with proper formatting
tree = ET.ElementTree(iwn_root)
save_pretty_xml(tree, plug_att)
